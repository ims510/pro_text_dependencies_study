# %% [markdown]
# This code was written as part of the Pro-Text project, focusing on the relation between syntactic dependencies and pauses made when typing texts.

# %%
data_file = open("test.conll", "r")
data = []

# Read file and split into sentences as lists of lines
current_sentence = []
for line in data_file:
	if line == "\n":
		if current_sentence:  # Ensure the sentence is not empty
			data.append(current_sentence)
		current_sentence = []
	else:
		current_sentence.append(line.strip())  # Remove newline characters

if current_sentence:  # Add the last sentence if file doesn't end with a newline
	data.append(current_sentence)

data_file.close()  # Close the file after reading

last_text_version = None

# Insert last_text_version where needed
for i in range(len(data)):
	if not data[i][0].startswith("# text_version"):
		if last_text_version is not None:
			data[i].insert(0, last_text_version)
	else:
		last_text_version = data[i][0]


for i in range(len(data)):
	expected_number = 1
	for j in range(2, len(data[i])):  # Assuming the first two lines are comments
		components = data[i][j].split('\t')
		# print(components)
		if len(components) > 1:  # Ensure the line is not a comment
			components[0] = str(expected_number)
			data[i][j] = '\t'.join(components)
			expected_number += 1


# # Print the updated data for verification
for sentence in data:
	for line in sentence:
		print(line)
#     print()  # Print a newline between sentences for clarity
# Out:
# # text_version=54
# # sentence_id=1
# 1	la	la	DET	DET	n=s|g=f	3	det	_	charID=3__char=l__charStatus=True__pause=7270|charID=4__char=a__charStatus=True__pause=16
# 2	violence	violence	NC	NC	n=s|g=f	4	suj	_	charID=6__char=v__charStatus=True__pause=141|charID=7__char=i__charStatus=True__pause=156|charID=8__char=o__charStatus=True__pause=141|charID=9__char=l__charStatus=True__pause=125|charID=10__char=e__charStatus=True__pause=343|charID=11__char=n__charStatus=True__pause=109|charID=12__char=c__charStatus=True__pause=343|charID=13__char=e__charStatus=True__pause=62
# 3	est	être	V	V	n=s|t=P|p=3	0	root	_	charID=16__char=e__charStatus=True__pause=3370|charID=17__char=s__charStatus=True__pause=202|charID=18__char=t__charStatus=True__pause=93
# 4	une	une	DET	DET	n=s|g=f	8	det	_	charID=40__char=u__charStatus=True__pause=796|charID=41__char=n__charStatus=True__pause=171|charID=42__char=e__charStatus=True__pause=109
# 5	chose	chose	NC	NC	n=s|g=f	4	obj	_	charID=44__char=c__charStatus=True__pause=140|charID=45__char=h__charStatus=True__pause=437|charID=46__char=o__charStatus=True__pause=187|charID=47__char=s__charStatus=True__pause=250|charID=48__char=e__charStatus=True__pause=78
# 6	qui	qui	PROREL	PROREL	n=s	30	mod	_	charID=50__char=q__charStatus=True__pause=140|charID=51__char=u__charStatus=True__pause=124|charID=52__char=i__charStatus=True__pause=125
# 7	ne	ne	ADV	ADV	_	12	mod	_	charID=54__char=n__charStatus=True__pause=110|charID=57__char=e__charStatus=True__pause=452
# 8	sert	_	NC	NC	_	30	suj	_	charID=59__char=s__charStatus=True__pause=203|charID=60__char=e__charStatus=True__pause=94|charID=61__char=r__charStatus=True__pause=94|charID=62__char=t__charStatus=True__pause=125
# 9	a	avoir	V	V	n=s|t=P|p=3	30	mod	_	charID=64__char=a__charStatus=True__pause=1591
# 10	rien	rien	PRO	PRO	n=s|g=m	30	suj	_	charID=66__char=r__charStatus=True__pause=109|charID=67__char=i__charStatus=True__pause=156|charID=68__char=e__charStatus=True__pause=109|charID=69__char=n__charStatus=True__pause=47
# 11	elle	elle	CLS	CLS	n=s|g=f|p=3	29	suj	_	charID=71__char=e__charStatus=True__pause=936|charID=72__char=l__charStatus=True__pause=296|charID=73__char=l__charStatus=True__pause=125|charID=74__char=e__charStatus=True__pause=94
# 12	ne	ne	ADV	ADV	_	29	mod	_	charID=76__char=n__charStatus=True__pause=171|charID=77__char=e__charStatus=True__pause=78
# 13	resoud	_	NPP	NPP	_	29	suj	_	charID=79__char=r__charStatus=True__pause=390|charID=80__char=e__charStatus=True__pause=109|charID=81__char=s__charStatus=True__pause=140|charID=82__char=o__charStatus=True__pause=499|charID=83__char=u__charStatus=True__pause=171|charID=84__char=d__charStatus=True__pause=265
# 14	pas	pas	ADV	ADV	_	20	mod	_	charID=86__char=p__charStatus=True__pause=1420|charID=87__char=a__charStatus=True__pause=141|charID=88__char=s__charStatus=True__pause=171
# 15	nos	nos	DET	DET	n=p|p=1|poss=p	20	det	_	charID=90__char=n__charStatus=True__pause=1965|charID=91__char=o__charStatus=True__pause=218|charID=92__char=s__charStatus=True__pause=203
# 16	problème	problème	NC	NC	n=s|g=m	17	mod	_	charID=94__char=p__charStatus=True__pause=998|charID=95__char=r__charStatus=True__pause=78|charID=96__char=o__charStatus=True__pause=46|charID=97__char=b__charStatus=True__pause=406|charID=98__char=l__charStatus=True__pause=328|charID=99__char=è__charStatus=True__pause=1154|charID=100__char=m__charStatus=True__pause=3339|charID=101__char=e__charStatus=True__pause=94
# 17	en	en	P	P	_	20	dep	_	charID=103__char=e__charStatus=True__pause=17145|charID=104__char=n__charStatus=True__pause=312
# 18	en	en	P	P	_	21	prep	_	charID=106__char=e__charStatus=True__pause=842|charID=107__char=n__charStatus=True__pause=110
# 19	plus	plus	ADV	ADV	_	22	mod	_	charID=109__char=p__charStatus=True__pause=125|charID=110__char=l__charStatus=True__pause=141|charID=111__char=u__charStatus=True__pause=156|charID=112__char=s__charStatus=True__pause=125
# 20	si	si	CS	CS	_	20	mod	_	charID=114__char=s__charStatus=True__pause=592|charID=115__char=i__charStatus=True__pause=531
# 21	quelq	_	ADV	ADV	_	29	mod	_	charID=117__char=q__charStatus=True__pause=483|charID=118__char=u__charStatus=True__pause=124|charID=119__char=e__charStatus=True__pause=219|charID=120__char=l__charStatus=True__pause=187|charID=121__char=q__charStatus=True__pause=1950
# 22	'	'	PONCT	PONCT	_	25	ponct	_	charID=122__char='__charStatus=True__pause=219
# 23	un	un	PRO	PRO	n=s|g=m	29	suj	_	charID=123__char=u__charStatus=True__pause=156|charID=124__char=n__charStatus=True__pause=156
# 24	t'	te	CLO	CLO	n=s|p=2	29	obj	_	charID=126__char=t__charStatus=True__pause=1201|charID=127__char='__charStatus=True__pause=234
# 25	insulte	insulter	V	V	n=s|t=P,S|p=1,3	14	mod_rel	_	charID=128__char=i__charStatus=True__pause=187|charID=129__char=n__charStatus=True__pause=187|charID=130__char=s__charStatus=True__pause=203|charID=131__char=u__charStatus=True__pause=218|charID=132__char=l__charStatus=True__pause=328|charID=133__char=t__charStatus=True__pause=5726|charID=134__char=e__charStatus=True__pause=62
# 26	est	être	V	V	n=s|t=P|p=3	8	mod_rel	_	charID=136__char=e__charStatus=True__pause=312|charID=137__char=s__charStatus=True__pause=187|charID=138__char=t__charStatus=True__pause=78
# 27	que	que	CS	CS	_	4	mod	_	charID=140__char=q__charStatus=True__pause=250|charID=141__char=u__charStatus=True__pause=452|charID=142__char=e__charStatus=True__pause=171
# 28	tu	taire	VPP	VPP	n=s|g=m|t=K	31	sub	_	charID=144__char=t__charStatus=True__pause=578|charID=145__char=u__charStatus=True__pause=93
# 29	repond	_	ADV	ADV	_	32	mod	_	charID=147__char=r__charStatus=True__pause=218|charID=148__char=e__charStatus=True__pause=171|charID=149__char=p__charStatus=True__pause=94|charID=150__char=o__charStatus=True__pause=140|charID=151__char=n__charStatus=True__pause=187|charID=152__char=d__charStatus=True__pause=266
# 30	avec	avec	P	P	_	32	mod	_	charID=154__char=a__charStatus=True__pause=218|charID=155__char=v__charStatus=True__pause=94|charID=156__char=e__charStatus=True__pause=31|charID=157__char=c__charStatus=True__pause=46
# 31	la	la	DET	DET	n=s|g=f	169	det	_	charID=159__char=l__charStatus=True__pause=359|charID=160__char=a__charStatus=True__pause=156
# 32	violence	violence	NC	NC	n=s|g=f	34	prep	_	charID=162__char=v__charStatus=True__pause=202|charID=163__char=i__charStatus=True__pause=265|charID=164__char=o__charStatus=True__pause=125|charID=165__char=l__charStatus=True__pause=141|charID=166__char=e__charStatus=True__pause=249|charID=167__char=n__charStatus=True__pause=109|charID=169__char=c__charStatus=True__pause=na|charID=170__char=e__charStatus=True__pause=140
# 33	après	après	P	P	_	4	mod	_	charID=172__char=a__charStatus=True__pause=234|charID=175__char=p__charStatus=True__pause=640|charID=176__char=r__charStatus=True__pause=78|charID=177__char=è__charStatus=True__pause=1217|charID=178__char=s__charStatus=True__pause=281
# 34	sa	sa	DET	DET	n=s|g=f|p=3|poss=s	41	det	_	charID=180__char=s__charStatus=True__pause=219|charID=181__char=a__charStatus=True__pause=172
# 35	va	_	NC	NC	_	39	prep	_	charID=183__char=v__charStatus=True__pause=140|charID=184__char=a__charStatus=True__pause=78
# 36	continuer	continuer	VINF	VINF	t=W	4	mod	_	charID=186__char=c__charStatus=True__pause=328|charID=191__char=o__charStatus=True__pause=842|charID=192__char=n__charStatus=True__pause=219|charID=193__char=t__charStatus=True__pause=281|charID=194__char=i__charStatus=True__pause=62|charID=195__char=n__charStatus=True__pause=577|charID=196__char=u__charStatus=True__pause=234|charID=197__char=e__charStatus=True__pause=312|charID=198__char=r__charStatus=True__pause=94
# 37	.	.	PONCT	PONCT	_	44	ponct	_	charID=808__char=.__charStatus=True__pause=2137
# # text_version=54
# # sentence_id=2
# 1	mais	mais	CC	CC	_	0	root	_	charID=200__char=m__charStatus=True__pause=562|charID=201__char=a__charStatus=True__pause=172|charID=202__char=i__charStatus=True__pause=78|charID=203__char=s__charStatus=True__pause=63
# 2	si	si	CS	CS	_	66	mod	_	charID=205__char=s__charStatus=True__pause=188|charID=206__char=i__charStatus=True__pause=468
# 3	tu	tu	CLS	CLS	n=s|p=2	48	suj	_	charID=208__char=t__charStatus=True__pause=873|charID=209__char=u__charStatus=True__pause=125
# 4	parle	parler	V	V	n=s|t=P,S|p=1,3	46	sub	_	charID=211__char=p__charStatus=True__pause=296|charID=212__char=a__charStatus=True__pause=234|charID=213__char=r__charStatus=True__pause=47|charID=214__char=l__charStatus=True__pause=265|charID=215__char=e__charStatus=True__pause=109
# 5	avec	avec	P	P	_	48	mod	_	charID=217__char=a__charStatus=True__pause=125|charID=218__char=v__charStatus=True__pause=31|charID=219__char=e__charStatus=True__pause=62|charID=220__char=c__charStatus=True__pause=32
# 6	une	une	DET	DET	n=s|g=f	51	det	_	charID=222__char=u__charStatus=True__pause=203|charID=223__char=n__charStatus=True__pause=234|charID=224__char=e__charStatus=True__pause=125
# 7	personne	personne	NC	NC	n=s|g=f	49	prep	_	charID=226__char=p__charStatus=True__pause=312|charID=227__char=e__charStatus=True__pause=203|charID=228__char=r__charStatus=True__pause=109|charID=229__char=s__charStatus=True__pause=218|charID=230__char=o__charStatus=True__pause=390|charID=231__char=n__charStatus=True__pause=328|charID=232__char=n__charStatus=True__pause=141|charID=233__char=e__charStatus=True__pause=78
# 8	pour	pour	P	P	_	48	mod	_	charID=235__char=p__charStatus=True__pause=266|charID=253__char=o__charStatus=True__pause=359|charID=254__char=u__charStatus=True__pause=140|charID=255__char=r__charStatus=True__pause=405
# 9	après	après	P	P	_	56	prep	_	charID=243__char=a__charStatus=True__pause=171|charID=244__char=p__charStatus=True__pause=406|charID=245__char=r__charStatus=True__pause=483|charID=246__char=è__charStatus=True__pause=1420|charID=247__char=s__charStatus=True__pause=484
# 10	te	te	CLO	CLO	n=s|p=2	66	mod	_	charID=256__char=t__charStatus=True__pause=4695|charID=257__char=e__charStatus=True__pause=78
# 11	battre	battre	VINF	VINF	t=W	57	aff	_	charID=259__char=b__charStatus=True__pause=1981|charID=260__char=a__charStatus=True__pause=390|charID=261__char=t__charStatus=True__pause=125|charID=262__char=t__charStatus=True__pause=125|charID=263__char=r__charStatus=True__pause=218|charID=264__char=e__charStatus=True__pause=110
# 12	avec	avec	P	P	_	58	mod	_	charID=266__char=a__charStatus=True__pause=296|charID=267__char=v__charStatus=True__pause=62|charID=268__char=e__charStatus=True__pause=62|charID=269__char=c__charStatus=True__pause=31
# 13	lui	lui	PRO	PRO	n=s|g=m|p=3	59	prep	_	charID=271__char=l__charStatus=True__pause=328|charID=272__char=u__charStatus=True__pause=188|charID=273__char=i__charStatus=True__pause=1061
# 14	sa	sa	DET	DET	n=s|g=f|p=3|poss=s	65	det	_	charID=277__char=s__charStatus=True__pause=203|charID=278__char=a__charStatus=True__pause=31
# 15	sert	_	NC	NC	_	58	obj	_	charID=280__char=s__charStatus=True__pause=109|charID=285__char=e__charStatus=True__pause=343|charID=286__char=r__charStatus=True__pause=343|charID=287__char=t__charStatus=True__pause=234
# 16	a	avoir	V	V	n=s|t=P|p=3	45	dep_coord	_	charID=289__char=a__charStatus=True__pause=187
# 17	rien	rien	PRO	PRO	n=s|g=m	66	obj	_	charID=291__char=r__charStatus=True__pause=93|charID=292__char=i__charStatus=True__pause=187|charID=299__char=e__charStatus=True__pause=858|charID=300__char=n__charStatus=True__pause=110
# 18	tu	taire	VPP	VPP	n=s|g=m|t=K	69	mod	_	charID=302__char=t__charStatus=True__pause=1170|charID=303__char=u__charStatus=True__pause=343
# 19	peux	pouvoir	V	V	n=s|t=P|p=1,2	66	mod	_	charID=305__char=p__charStatus=True__pause=312|charID=306__char=e__charStatus=True__pause=1622|charID=307__char=u__charStatus=True__pause=94|charID=308__char=x__charStatus=True__pause=156
# 20	l'	le	CLO	CLO	n=s|p=3	73	obj	_	charID=310__char=l__charStatus=True__pause=15616|charID=311__char='__charStatus=True__pause=78
# 21	ignorer	ignorer	VINF	VINF	t=W	71	obj	_	charID=312__char=i__charStatus=True__pause=343|charID=313__char=g__charStatus=True__pause=1108|charID=314__char=n__charStatus=True__pause=187|charID=315__char=o__charStatus=True__pause=280|charID=316__char=r__charStatus=True__pause=250|charID=317__char=e__charStatus=True__pause=93|charID=318__char=r__charStatus=True__pause=141
# 22	dans	dans	P	P	_	73	mod	_	charID=322__char=d__charStatus=True__pause=375|charID=323__char=a__charStatus=True__pause=436|charID=324__char=n__charStatus=True__pause=94|charID=325__char=s__charStatus=True__pause=47
# 23	se	se	CLR	CLR	n=p,s|p=3	77	det	_	charID=327__char=s__charStatus=True__pause=125|charID=328__char=e__charStatus=True__pause=62
# 24	cas	cas	NC	NC	g=m	75	prep	_	charID=330__char=c__charStatus=True__pause=156|charID=331__char=a__charStatus=True__pause=110|charID=332__char=s__charStatus=True__pause=47
# 25	là	là	ADV	ADV	_	73	mod	_	charID=334__char=l__charStatus=True__pause=19796|charID=335__char=à__charStatus=True__pause=2527
# 26	.	.	PONCT	PONCT	_	78	ponct	_	charID=348__char=.__charStatus=True__pause=1685
# # text_version=54
# # sentence_id=3
# 1	il	il	CLS	CLS	n=s|g=m|p=3	83	suj	_	charID=350__char=i__charStatus=True__pause=1217|charID=351__char=l__charStatus=True__pause=125
# 2	faut	falloir	V	V	n=s|t=P|p=3	0	root	_	charID=353__char=f__charStatus=True__pause=624|charID=354__char=a__charStatus=True__pause=234|charID=355__char=u__charStatus=True__pause=62|charID=356__char=t__charStatus=True__pause=172
# 3	que	que	CS	CS	_	83	obj	_	charID=484__char=q__charStatus=True__pause=640|charID=485__char=u__charStatus=True__pause=62|charID=486__char=e__charStatus=True__pause=125
# 4	tu	_	NC	NC	_	101	suj	_	charID=488__char=t__charStatus=True__pause=203|charID=489__char=u__charStatus=True__pause=515
# 5	soit	être	VS	VS	n=s|t=S|p=3	99	sub	_	charID=491__char=s__charStatus=True__pause=156|charID=492__char=o__charStatus=True__pause=109|charID=493__char=i__charStatus=True__pause=141|charID=494__char=t__charStatus=True__pause=219
# 6	plus	plus	ADV	ADV	_	101	mod	_	charID=496__char=p__charStatus=True__pause=390|charID=497__char=l__charStatus=True__pause=156|charID=498__char=u__charStatus=True__pause=171|charID=499__char=s__charStatus=True__pause=141
# 7	intelligent	intelligent	ADJ	ADJ	n=s|g=m	101	ats	_	charID=501__char=i__charStatus=True__pause=374|charID=502__char=n__charStatus=True__pause=171|charID=503__char=t__charStatus=True__pause=639|charID=504__char=e__charStatus=True__pause=249|charID=505__char=l__charStatus=True__pause=265|charID=506__char=l__charStatus=True__pause=125|charID=507__char=i__charStatus=True__pause=140|charID=508__char=g__charStatus=True__pause=717|charID=509__char=e__charStatus=True__pause=187|charID=510__char=n__charStatus=True__pause=62|charID=511__char=t__charStatus=True__pause=1108
# 8	que	que	CS	CS	_	83	mod	_	charID=513__char=q__charStatus=True__pause=187|charID=514__char=u__charStatus=True__pause=109|charID=515__char=e__charStatus=True__pause=156
# 9	l'	le	DET	DET	n=s	106	det	_	charID=517__char=l__charStatus=True__pause=967|charID=518__char='__charStatus=True__pause=390
# 10	autre	autre	PRO	PRO	n=s|g=f,m	104	sub	_	charID=519__char=a__charStatus=True__pause=125|charID=520__char=u__charStatus=True__pause=250|charID=521__char=t__charStatus=True__pause=171|charID=522__char=r__charStatus=True__pause=140|charID=523__char=e__charStatus=True__pause=110
# 11	comme	comme	P	P	_	106	dep	_	charID=525__char=c__charStatus=True__pause=2340|charID=526__char=o__charStatus=True__pause=109|charID=527__char=m__charStatus=True__pause=218|charID=528__char=m__charStatus=True__pause=125|charID=529__char=e__charStatus=True__pause=109
# 12	ça	ça	PRO	PRO	n=s	107	prep	_	charID=531__char=ç__charStatus=True__pause=1716|charID=532__char=a__charStatus=True__pause=125
# 13	tu	taire	ADJ	ADJ	n=s|g=m|t=K	108	mod	_	charID=534__char=t__charStatus=True__pause=562|charID=535__char=u__charStatus=True__pause=546
# 14	te	te	CLO	CLO	n=s|p=2	0	_	_	charID=537__char=t__charStatus=True__pause=234|charID=538__char=e__charStatus=True__pause=219
# 15	fera	faire	V	V	n=s|t=F|p=3	0	_	_	charID=542__char=f__charStatus=True__pause=1498|charID=543__char=e__charStatus=True__pause=94|charID=544__char=r__charStatus=True__pause=62|charID=545__char=a__charStatus=True__pause=187
# 16	pas	pas	ADV	ADV	_	112	mod	_	charID=547__char=p__charStatus=True__pause=499|charID=548__char=a__charStatus=True__pause=343|charID=549__char=s__charStatus=True__pause=156
# 17	punir	punir	VINF	VINF	t=W	112	obj	_	charID=551__char=p__charStatus=True__pause=390|charID=552__char=u__charStatus=True__pause=390|charID=553__char=n__charStatus=True__pause=187|charID=554__char=i__charStatus=True__pause=187|charID=555__char=r__charStatus=True__pause=296
# 18	et	et	CC	CC	_	112	coord	_	charID=557__char=e__charStatus=True__pause=905|charID=558__char=t__charStatus=True__pause=46
# 19	puis	_	ADV	ADV	_	116	mod	_	charID=575__char=p__charStatus=True__pause=250|charID=576__char=u__charStatus=True__pause=202|charID=577__char=i__charStatus=True__pause=141|charID=578__char=s__charStatus=True__pause=171
# 20	tu	taire	VPP	VPP	n=s|g=m|t=K	115	dep_coord	_	charID=560__char=t__charStatus=True__pause=561|charID=561__char=u__charStatus=True__pause=94
# 21	n'	ne	ADV	ADV	_	116	mod	_	charID=563__char=n__charStatus=True__pause=1123|charID=564__char='__charStatus=True__pause=63
# 22	aura	avoir	V	V	n=s|t=F|p=3	115	root	_	charID=565__char=a__charStatus=True__pause=297|charID=566__char=u__charStatus=True__pause=358|charID=567__char=r__charStatus=True__pause=218|charID=568__char=a__charStatus=True__pause=437
# 23	pas	pas	ADV	ADV	_	118	mod	_	charID=570__char=p__charStatus=True__pause=390|charID=571__char=a__charStatus=True__pause=124|charID=572__char=s__charStatus=True__pause=125
# 24	de	de	P	P	_	118	mod	_	charID=579__char=d__charStatus=True__pause=3042|charID=580__char=e__charStatus=True__pause=125
# 25	problème	problème	NC	NC	n=s|g=m	121	prep	_	charID=582__char=p__charStatus=True__pause=796|charID=583__char=r__charStatus=True__pause=343|charID=584__char=o__charStatus=True__pause=15|charID=585__char=b__charStatus=True__pause=234|charID=586__char=l__charStatus=True__pause=468|charID=587__char=è__charStatus=True__pause=890|charID=588__char=m__charStatus=True__pause=312|charID=589__char=e__charStatus=True__pause=156
# 26	.	.	PONCT	PONCT	_	122	ponct	_	charID=591__char=.__charStatus=True__pause=41652
# 27	mais	mais	CC	CC	_	118	coord	_	charID=609__char=m__charStatus=True__pause=1342|charID=610__char=a__charStatus=True__pause=187|charID=611__char=i__charStatus=True__pause=2340|charID=612__char=s__charStatus=True__pause=234
# 28	après	après	ADV	ADV	_	131	mod	_	charID=614__char=a__charStatus=True__pause=359|charID=615__char=p__charStatus=True__pause=203|charID=616__char=r__charStatus=True__pause=733|charID=617__char=è__charStatus=True__pause=1326|charID=618__char=s__charStatus=True__pause=624
# 29	il	il	CLS	CLS	n=s|g=m|p=3	131	suj	_	charID=622__char=i__charStatus=True__pause=265|charID=623__char=l__charStatus=True__pause=171
# 30	y	y	CLO	CLO	_	131	aff	_	charID=625__char=y__charStatus=True__pause=265
# 31	a	avoir	V	V	n=s|t=P|p=3	126	dep_coord	_	charID=627__char=a__charStatus=True__pause=140
# 32	deux	deux	DET	DET	s=card|n=p	133	det	_	charID=629__char=d__charStatus=True__pause=858|charID=630__char=e__charStatus=True__pause=125|charID=631__char=u__charStatus=True__pause=109|charID=632__char=x__charStatus=True__pause=171
# 33	chose	chose	NC	NC	n=s|g=f	131	obj	_	charID=634__char=c__charStatus=True__pause=312|charID=635__char=h__charStatus=True__pause=249|charID=636__char=o__charStatus=True__pause=328|charID=637__char=s__charStatus=True__pause=312|charID=638__char=e__charStatus=True__pause=156
# 34	que	que	PROREL	PROREL	_	136	suj	_	charID=640__char=q__charStatus=True__pause=374|charID=641__char=u__charStatus=True__pause=62|charID=642__char=e__charStatus=True__pause=140
# 35	tu	taire	VPP	VPP	n=s|g=m|t=K	134	ponct	_	charID=644__char=t__charStatus=True__pause=203|charID=645__char=u__charStatus=True__pause=406
# 36	peux	pouvoir	V	V	n=s|t=P|p=1,2	133	mod_rel	_	charID=647__char=p__charStatus=True__pause=94|charID=648__char=e__charStatus=True__pause=141|charID=649__char=u__charStatus=True__pause=156|charID=650__char=x__charStatus=True__pause=515
# 37	faire	faire	VINF	VINF	t=W	136	obj	_	charID=652__char=f__charStatus=True__pause=2153|charID=653__char=a__charStatus=True__pause=203|charID=654__char=i__charStatus=True__pause=109|charID=655__char=r__charStatus=True__pause=203|charID=656__char=e__charStatus=True__pause=93
# 38	?	?	PONCT	PONCT	_	137	ponct	_	charID=809__char=?__charStatus=False__pause=30748
# 39	soit	être	VS	VS	n=s|t=S|p=3	146	mod	_	charID=658__char=s__charStatus=True__pause=250|charID=659__char=o__charStatus=True__pause=203|charID=660__char=i__charStatus=True__pause=109|charID=661__char=t__charStatus=True__pause=203
# 40	tu	taire	VPP	VPP	n=s|g=m|t=K	146	mod	_	charID=663__char=t__charStatus=True__pause=577|charID=664__char=u__charStatus=True__pause=94
# 41	le	le	CLO	CLO	n=s|g=m|p=3	141	obj	_	charID=666__char=l__charStatus=True__pause=109|charID=667__char=e__charStatus=True__pause=171
# 42	pardonne	pardonner	V	V	n=s|t=P,S|p=1,3	139	mod	_	charID=669__char=p__charStatus=True__pause=920|charID=670__char=a__charStatus=True__pause=109|charID=671__char=r__charStatus=True__pause=141|charID=672__char=d__charStatus=True__pause=203|charID=673__char=o__charStatus=True__pause=296|charID=674__char=n__charStatus=True__pause=234|charID=675__char=n__charStatus=True__pause=124|charID=676__char=e__charStatus=True__pause=141
# 43	ou	ou	CC	CC	_	141	coord	_	charID=678__char=o__charStatus=True__pause=499|charID=679__char=u__charStatus=True__pause=172
# 44	soit	être	VS	VS	n=s|t=S|p=3	144	aux_tps	_	charID=681__char=s__charStatus=True__pause=265|charID=682__char=o__charStatus=True__pause=94|charID=683__char=i__charStatus=True__pause=109|charID=684__char=t__charStatus=True__pause=234
# 45	tu	taire	VPP	VPP	n=s|g=m|t=K	142	dep_coord	_	charID=686__char=t__charStatus=True__pause=234|charID=687__char=u__charStatus=True__pause=94
# 46	l'	le	CLO	CLO	n=s|p=3	146	obj	_	charID=689__char=l__charStatus=True__pause=266|charID=690__char='__charStatus=True__pause=515
# 47	ignore	ignorer	V	V	n=s|t=P,S|p=1,3	112	mod	_	charID=691__char=i__charStatus=True__pause=266|charID=692__char=g__charStatus=True__pause=764|charID=693__char=n__charStatus=True__pause=219|charID=694__char=o__charStatus=True__pause=359|charID=695__char=r__charStatus=True__pause=327|charID=696__char=e__charStatus=True__pause=172
# 48	tu	taire	VPP	VPP	n=s|g=m|t=K	146	ats	_	charID=752__char=t__charStatus=True__pause=78|charID=753__char=u__charStatus=True__pause=93
# 49	l'	le	DET	DET	n=s	158	det	_	charID=755__char=l__charStatus=True__pause=499|charID=756__char='__charStatus=True__pause=47
# 50	adresse	adresse	NC	NC	n=s|g=f	156	obj	_	charID=757__char=a__charStatus=True__pause=406|charID=758__char=d__charStatus=True__pause=327|charID=759__char=r__charStatus=True__pause=203|charID=760__char=e__charStatus=True__pause=671|charID=761__char=s__charStatus=True__pause=156|charID=762__char=s__charStatus=True__pause=125|charID=763__char=e__charStatus=True__pause=156
# 51	plus	plus	ADV	ADV	_	161	mod	_	charID=765__char=p__charStatus=True__pause=780|charID=766__char=l__charStatus=True__pause=141|charID=767__char=u__charStatus=True__pause=203|charID=768__char=s__charStatus=True__pause=156
# 52	la	la	DET	DET	n=s|g=f	161	det	_	charID=770__char=l__charStatus=True__pause=374|charID=771__char=a__charStatus=True__pause=156
# 53	parole	parole	NC	NC	n=s|g=f	158	mod	_	charID=773__char=p__charStatus=True__pause=375|charID=774__char=a__charStatus=True__pause=312|charID=775__char=r__charStatus=True__pause=94|charID=776__char=o__charStatus=True__pause=1778|charID=777__char=l__charStatus=True__pause=156|charID=778__char=e__charStatus=True__pause=219
# 54	c'	ce	CLS	CLS	_	163	suj	_	charID=780__char=c__charStatus=True__pause=1872|charID=781__char='__charStatus=True__pause=187
# 55	est	être	V	V	n=s|t=P|p=3	112	mod	_	charID=782__char=e__charStatus=True__pause=78|charID=783__char=s__charStatus=True__pause=78|charID=784__char=t__charStatus=True__pause=47
# 56	a	avoir	V	V	n=s|t=P|p=3	112	mod	_	charID=786__char=a__charStatus=True__pause=390
# 57	toi	toi	PRO	PRO	n=s|p=2	164	obj	_	charID=788__char=t__charStatus=True__pause=280|charID=789__char=o__charStatus=True__pause=109|charID=790__char=i__charStatus=True__pause=93
# 58	de	de	P	P	_	164	mod	_	charID=792__char=d__charStatus=True__pause=218|charID=793__char=e__charStatus=True__pause=31
# 59	choisir	choisir	VINF	VINF	t=W	166	prep	_	charID=795__char=c__charStatus=True__pause=125|charID=796__char=h__charStatus=True__pause=32|charID=797__char=o__charStatus=True__pause=234|charID=798__char=i__charStatus=True__pause=109|charID=799__char=s__charStatus=True__pause=250|charID=800__char=i__charStatus=True__pause=577|charID=801__char=r__charStatus=True__pause=156
# 60	.	.	PONCT	PONCT	_	167	ponct	_	charID=802__char=.__charStatus=True__pause=4571

# %%
def clean_conll(file):
	data_file = open(file, "r")
	data = []

	# Read file and split into sentences as lists of lines
	current_sentence = []
	for line in data_file:
		if line == "\n":
			if current_sentence:  # Ensure the sentence is not empty
				data.append(current_sentence)
			current_sentence = []
		else:
			current_sentence.append(line.strip())  # Remove newline characters

	if current_sentence:  # Add the last sentence if file doesn't end with a newline
		data.append(current_sentence)

	data_file.close()  # Close the file after reading

	last_text_version = None

	# Insert last_text_version where needed
	for i in range(len(data)):
		if not data[i][0].startswith("# text_version"):
			if last_text_version is not None:
				data[i].insert(0, last_text_version)
		else:
			last_text_version = data[i][0]


	for i in range(len(data)):
		expected_number = 1
		for j in range(2, len(data[i])):  # Assuming the first two lines are comments
			components = data[i][j].split('\t')
			# print(components)
			if len(components) > 1:  # Ensure the line is not a comment
				components[0] = str(expected_number)
				data[i][j] = '\t'.join(components)
				expected_number += 1

	return data

# %%
import stanza
from stanza.models.common.doc import Document

nlp = stanza.Pipeline('fr', processors='depparse', depparse_pretagged=True)
# Out:
# 2024-07-12 16:50:05 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-07-12 16:50:05 INFO: Downloaded file to /Users/madalina/stanza_resources/resources.json
# 2024-07-12 16:50:05 INFO: Loading these models for language: fr (French):
# ===============================
# | Processor | Package         |
# -------------------------------
# | depparse  | combined_charlm |
# ===============================
#
# 2024-07-12 16:50:05 INFO: Using device: cpu
# 2024-07-12 16:50:05 INFO: Loading: depparse
# 2024-07-12 16:50:05 INFO: Done loading processors!

# %%
def create_new_conll(data, output_file):
	miscs = []
	with open (output_file, "w", encoding="utf-8") as f:
		for i in range(len(data)):
			conll_sent = data[i].split("\n")
			text_version = conll_sent [0] #literally: # text_version=0
			f.write(text_version + "\n")
			sentence_id = conll_sent[1] #literally: # sentence_id=1
			f.write(sentence_id + "\n")
			sentence_complete = conll_sent[2:]
			sentence = ""
			for token in sentence_complete:
				elements = token.split("\t")
				miscs.append(elements[9] if len(elements) > 1 else "")
				if len(elements) > 1:
					sentence += elements[1] + " "
			f.write(f"# text = {sentence}\n")
			doc = nlp(sentence)
			print(doc)
			for i in range(len(doc.sentences[0].words)):
				token = doc.sentences[0].words[i]
				xpos = token.xpos if not "None" else "_"
				deps = token.deps if not "None" else "_"
				f.write(f"{token.id}\t{token.text}\t{token.lemma}\t{token.pos}\t{xpos}\t{token.feats}\t{token.head}\t{token.deprel}\t{deps}\t{miscs[i]}\n")
			f.write("\n")
	print(f"File {output_file} created")

# %%
def extract_data(file):
	data_file = open(file, "r", encoding="utf-8")
	sentence = ""
	data = []
	for line in data_file:
		if line[0] == "\n":
			data.append(sentence)
			sentence = ""
		else:
			sentence = sentence + line
	return data

# %%
import stanza


nlp = stanza.Pipeline('fr', processors='tokenize, pos, lemma, depparse')
# Out:
# 2024-07-17 13:55:01 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-07-17 13:55:01 INFO: Downloaded file to /Users/madalina/stanza_resources/resources.json
# 2024-07-17 13:55:01 WARNING: Language fr package default expects mwt, which has been added
# 2024-07-17 13:55:02 INFO: Loading these models for language: fr (French):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# 2024-07-17 13:55:02 INFO: Using device: cpu
# 2024-07-17 13:55:02 INFO: Loading: tokenize
# 2024-07-17 13:55:02 INFO: Loading: mwt
# 2024-07-17 13:55:02 INFO: Loading: pos
# 2024-07-17 13:55:02 INFO: Loading: lemma
# 2024-07-17 13:55:02 INFO: Loading: depparse
# 2024-07-17 13:55:02 INFO: Done loading processors!

# %%
def get_token_text_from_misc(misc):
	misc = misc.split("|")
	word = ""
	for char_details in misc:
		char_details = char_details.split("__")
		char = char_details[1].split("=")[1]
		word += char
	return word

# %%
original_list= [['1', 'Alors', 'alors', 'ADV', 'ADV', '_', '92', 'mod', '_', 'charID=408__char=A__charStatus=True__pause=6942|charID=409__char=l__charStatus=True__pause=780|charID=410__char=o__charStatus=True__pause=140|charID=411__char=r__charStatus=True__pause=359|charID=412__char=s__charStatus=True__pause=312'], ['2', 'a', 'avoir', 'V', 'V', 'n=s|t=P|p=3', '0', 'root', '_', 'charID=414__char=a__charStatus=True__pause=312'], ['3', 'la', 'la', 'DET', 'DET', 'n=s|g=f', '94', 'det', '_', 'charID=416__char=l__charStatus=True__pause=156|charID=417__char=a__charStatus=True__pause=265'], ['4', 'fin', 'fin', 'NC', 'NC', 'n=s', '92', 'obj', '_', 'charID=419__char=f__charStatus=True__pause=312|charID=420__char=i__charStatus=True__pause=219|charID=421__char=n__charStatus=True__pause=187'], ['5', 'du', 'de', 'P+D', 'P+D', 'n=s|g=m', '94', 'dep', '_', 'charID=423__char=d__charStatus=True__pause=281|charID=424__char=u__charStatus=True__pause=328'], ['6', 'cours', 'cour', 'NC', 'NC', 'n=p|g=f', '95', 'prep', '_', 'charID=426__char=c__charStatus=True__pause=171|charID=427__char=o__charStatus=True__pause=171|charID=428__char=u__charStatus=True__pause=249|charID=429__char=r__charStatus=True__pause=296|charID=430__char=s__charStatus=True__pause=827'], ['7', "j'", 'je', 'CLS', 'CLS', 'n=s|p=1', '98', 'suj', '_', "charID=432__char=j__charStatus=True__pause=7379|charID=433__char='__charStatus=True__pause=359"], ['8', 'ai', 'avoir', 'V', 'V', 'n=s|t=P|p=1', '92', 'mod', '_', 'charID=434__char=a__charStatus=True__pause=296|charID=435__char=i__charStatus=True__pause=328'], ['9', 'etait', '_', 'ADV', 'ADV', '_', '98', 'mod', '_', 'charID=437__char=e__charStatus=True__pause=375|charID=438__char=t__charStatus=True__pause=358|charID=439__char=a__charStatus=True__pause=312|charID=440__char=i__charStatus=True__pause=202|charID=441__char=t__charStatus=True__pause=218'], ['10', 'voir', '_', 'I', 'I', '_', '0', '_', '_', 'charID=443__char=v__charStatus=True__pause=234|charID=444__char=o__charStatus=True__pause=172|charID=445__char=i__charStatus=True__pause=141|charID=446__char=r__charStatus=True__pause=265']]
stanza_list = [[1, 'Alors', 'alors', 'ADV', '_', None, 11, 'advmod', '_', 'charID=408__char=A__charStatus=True__pause=6942|charID=409__char=l__charStatus=True__pause=780|charID=410__char=o__charStatus=True__pause=140|charID=411__char=r__charStatus=True__pause=359|charID=412__char=s__charStatus=True__pause=312'], [2, 'a', 'à', 'ADP', '_', 'Typo=Yes', 4, 'case', '_', 'charID=414__char=a__charStatus=True__pause=312'], [3, 'la', 'le', 'DET', '_', 'Definite=Def|Gender=Fem|Number=Sing|PronType=Art', 4, 'det', '_', 'charID=416__char=l__charStatus=True__pause=156|charID=417__char=a__charStatus=True__pause=265'], [4, 'fin', 'fin', 'NOUN', '_', 'Gender=Fem|Number=Sing', 11, 'obl:mod', '_', 'charID=419__char=f__charStatus=True__pause=312|charID=420__char=i__charStatus=True__pause=219|charID=421__char=n__charStatus=True__pause=187'], [5, 'de', 'de', 'ADP', '_', None, 7, 'case', '_', 'charID=419__char=f__charStatus=True__pause=312|charID=420__char=i__charStatus=True__pause=219|charID=421__char=n__charStatus=True__pause=187'], [6, 'le', 'le', 'DET', '_', 'Definite=Def|Gender=Masc|Number=Sing|PronType=Art', 7, 'det', '_', 'charID=419__char=f__charStatus=True__pause=312|charID=420__char=i__charStatus=True__pause=219|charID=421__char=n__charStatus=True__pause=187'], [7, 'cours', 'cours', 'NOUN', '_', 'Gender=Masc|Number=Sing', 4, 'nmod', '_', 'charID=419__char=f__charStatus=True__pause=312|charID=420__char=i__charStatus=True__pause=219|charID=421__char=n__charStatus=True__pause=187'], [8, "j'", 'moi', 'PRON', '_', 'Emph=No|Number=Sing|Person=1|PronType=Prs', 11, 'nsubj', '_', 'charID=419__char=f__charStatus=True__pause=312|charID=420__char=i__charStatus=True__pause=219|charID=421__char=n__charStatus=True__pause=187'], [9, 'ai', 'avoir', 'AUX', '_', 'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin', 11, 'aux:tense', '_', 'charID=419__char=f__charStatus=True__pause=312|charID=420__char=i__charStatus=True__pause=219|charID=421__char=n__charStatus=True__pause=187'], [10, 'etait', 'être', 'AUX', '_', 'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 11, 'aux:pass', '_', 'charID=419__char=f__charStatus=True__pause=312|charID=420__char=i__charStatus=True__pause=219|charID=421__char=n__charStatus=True__pause=187'], [11, 'voir', 'voir', 'VERB', '_', 'VerbForm=Inf', 0, 'root', '_', 'charID=419__char=f__charStatus=True__pause=312|charID=420__char=i__charStatus=True__pause=219|charID=421__char=n__charStatus=True__pause=187']]

# %%
new_list = []
head = ""
min_len = min(len(original_list), len(stanza_list))
if min_len == len(original_list):
	print("Entered if min_len == len(original_list)")
	for i in range(min_len):
		print(f"i: {i}")
		orig_misc = original_list[i][9]
		stanza_misc = stanza_list[i][9]
		if orig_misc == stanza_misc:
			print("Entered if orig_misc == stanza_misc")
			print(f"int(stanza_list[i][6]) = {int(stanza_list[i][6])}")
			new_list.append(stanza_list[i])
			if int(stanza_list[i][6]) == 0:
				head = stanza_list[i]
		else:
			print("Entered else orig_misc == stanza_misc")
			new_element = [stanza_list[i][0], original_list[i][1], original_list[i][2], stanza_list[i][3], stanza_list[i][4], stanza_list[i][5], stanza_list[i][6], stanza_list[i][7], stanza_list[i][8], orig_misc]
			print(f"int(new_element[6]) = {int(new_element[6])}")
			if int(new_element[6]) == 0:
				head = new_element
			new_list.append(new_element)
else:
	print("Entered else min_len == len(original_list)")
	for i in range(min_len):
		print(f"i: {i}")
		orig_misc = original_list[i][9]
		stanza_misc = stanza_list[i][9]
		if orig_misc == stanza_misc:
			print("Entered if orig_misc == stanza_misc")
			new_list.append(stanza_list[i])
			print(f"int(stanza_list[i][6]) = {int(stanza_list[i][6])}")
			if int(stanza_list[i][6]) == 0:
				head = stanza_list[i]
		else:
			print("Entered else orig_misc == stanza_misc")
			new_element_1 = [int(original_list[i][0]), original_list[i][1], original_list[i][2], stanza_list[i][3], stanza_list[i][4], stanza_list[i][5], stanza_list[i][6], stanza_list[i][7], stanza_list[i][8], orig_misc]
			new_element_2 = [int(original_list[i+1][0]), original_list[i+1][1], original_list[i+1][2], stanza_list[i][3], stanza_list[i][4], stanza_list[i][5], stanza_list[i][6], stanza_list[i][7], original_list[i+1][8], original_list[i+1][9]]
			print(f"int(new_element_1[6]) = {int(new_element_1[6])}")
			print(f"int(new_element_2[6]) = {int(new_element_2[6])}")
			if int(new_element_1[6]) == 0:
				head = new_element_1
			elif int(new_element_2[6]) == 0:
				head = new_element_2
			new_list.append(new_element_1)
			new_list.append(new_element_2)

if head == "":
	for token in new_list:
		if int(token[6]) == 0:
			head = token

print(f"head: {head}")
# Check and adjust the head for each token
num_tokens = len(new_list)
for token in new_list:
	if int(token[6]) > num_tokens:
		token[6] = int(head[0])

# for element in new_list:
# 	print(element)

# print(f"Length of original list: {len(original_list)}")
# print(f"Length of stanza list: {len(stanza_list)}")
# print(f"Length of new list: {len(new_list)}")
# print(new_list)
# Out:
# Entered if min_len == len(original_list)
# i: 0
# Entered if orig_misc == stanza_misc
# int(stanza_list[i][6]) = 11
# i: 1
# Entered if orig_misc == stanza_misc
# int(stanza_list[i][6]) = 4
# i: 2
# Entered if orig_misc == stanza_misc
# int(stanza_list[i][6]) = 4
# i: 3
# Entered if orig_misc == stanza_misc
# int(stanza_list[i][6]) = 11
# i: 4
# Entered else orig_misc == stanza_misc
# int(new_element[6]) = 7
# i: 5
# Entered else orig_misc == stanza_misc
# int(new_element[6]) = 7
# i: 6
# Entered else orig_misc == stanza_misc
# int(new_element[6]) = 4
# i: 7
# Entered else orig_misc == stanza_misc
# int(new_element[6]) = 11
# i: 8
# Entered else orig_misc == stanza_misc
# int(new_element[6]) = 11
# i: 9
# Entered else orig_misc == stanza_misc
# int(new_element[6]) = 11
# head:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 58
#      56 for token in new_list:
#      57 	if int(token[6]) > num_tokens:
# ---> 58 		token[6] = int(head[0])
#      60 # for element in new_list:
#      61 # 	print(element)
#      62
#    (...)
#      65 # print(f"Length of new list: {len(new_list)}")
#      66 # print(new_list)
#
# IndexError: string index out of range

# %%
indices_heads = [(1, 3), (2, 3), (3, 0), (4, 5), (5, 3), (6, 7), (7, 5), (8, 10), (9, 10), (10, 5), (11, 3), (1, 2), (2, 0), (3, 2), (4, 9), (5, 9), (6, 9), (7, 9), (8, 9), (9, 2), (10, 12), (11, 12), (12, 2), (13, 16), (14, 16), (15, 16), (16, 12), (17, 19), (18, 19), (19, 16), (20, 2), (1, 4), (2, 4), (3, 4), (4, 0), (5, 7), (6, 7)]

sentences = []  # List to hold all sentences
current_sentence = []  # List to hold tuples of the current sentence

for pair in indices_heads:
	if pair[0] == 1 and current_sentence:  # If it's the start of a new sentence and not the first tuple
		sentences.append(current_sentence)  # Append the current sentence to sentences
		current_sentence = []  # Start a new current sentence
	current_sentence.append(pair)  # Add the current tuple to the current sentence

sentences.append(current_sentence)  # Append the last sentence after the loop finishes

# Now, sentences contains the separated sentences
for i, sentence in enumerate(sentences, start=1):
	print(f"Sentence {i}: {sentence}")
# Out:
# Sentence 1: [(1, 3), (2, 3), (3, 0), (4, 5), (5, 3), (6, 7), (7, 5), (8, 10), (9, 10), (10, 5), (11, 3)]
# Sentence 2: [(1, 2), (2, 0), (3, 2), (4, 9), (5, 9), (6, 9), (7, 9), (8, 9), (9, 2), (10, 12), (11, 12), (12, 2), (13, 16), (14, 16), (15, 16), (16, 12), (17, 19), (18, 19), (19, 16), (20, 2)]
# Sentence 3: [(1, 4), (2, 4), (3, 4), (4, 0), (5, 7), (6, 7)]

# %%
def correct_heads(indices_heads):

    sentences = []  # List to hold all sentences
    current_sentence = []  # List to hold tuples of the current sentence

    for pair in indices_heads:
        if pair[0] == 1 and current_sentence:  # If it's the start of a new sentence and not the first tuple
            sentences.append(current_sentence)  # Append the current sentence to sentences
            current_sentence = []  # Start a new current sentence
        current_sentence.append(pair)  # Add the current tuple to the current sentence

    sentences.append(current_sentence)  # Append the last sentence after the loop finishes

    for i, sentence in enumerate(sentences):
        for j, pair in enumerate(sentence):
            if pair[1] > sentence[-1][0]:  # If the head is outside the current sentence
                # Find the root of the current sentence (pair with second element == 0)
                root_pair = next((p for p in sentence if p[1] == 0), None)
                if root_pair:
                    # Replace the current pair with a new tuple
                    sentences[i][j] = (pair[0], root_pair[0])

    concat_list = sum(sentences, [])
    return concat_list

# %%
def merge_elements(original_list, stanza_list):
	new_list = []
	final_list = []
	print(f"original list: {original_list}")
	print(f"stanza list: {stanza_list}")
	min_len = min(len(original_list), len(stanza_list))
	if min_len == len(original_list):
		for i in range(min_len):
			orig_misc = original_list[i][9]
			stanza_misc = stanza_list[i][9]
			if orig_misc == stanza_misc:
				new_list.append(stanza_list[i])
			else:
				new_element = [stanza_list[i][0], original_list[i][1], original_list[i][2], stanza_list[i][3], stanza_list[i][4], stanza_list[i][5], stanza_list[i][6], stanza_list[i][7], stanza_list[i][8], orig_misc]
				new_list.append(new_element)
	else:
		for i in range(min_len):
			orig_misc = original_list[i][9]
			stanza_misc = stanza_list[i][9]
			if orig_misc == stanza_misc:
				new_list.append(stanza_list[i])
			else:
				new_element_1 = [int(original_list[i][0]), original_list[i][1], original_list[i][2], stanza_list[i][3], stanza_list[i][4], stanza_list[i][5], stanza_list[i][6], stanza_list[i][7], stanza_list[i][8], orig_misc]
				new_element_2 = [int(original_list[i+1][0]), original_list[i+1][1], original_list[i+1][2], stanza_list[i][3], stanza_list[i][4], stanza_list[i][5], stanza_list[i][6], stanza_list[i][7], original_list[i+1][8], original_list[i+1][9]]
				new_list.append(new_element_1)
				new_list.append(new_element_2)


	# Check and adjust the head for each token
	indices_heads = []
	for token in new_list:
		indices_heads.append((int(token[0]), int(token[6])))
	correct_indices_heads = correct_heads(indices_heads)
	for i in range(len(correct_indices_heads)):
		current_element = [int(correct_indices_heads[i][0]), new_list[i][1], new_list[i][2], new_list[i][3], new_list[i][4], new_list[i][5], correct_indices_heads[i][1], new_list[i][7], new_list[i][8], new_list[i][9]]
		final_list.append(current_element)
	
	return final_list

# %%
data = clean_conll("test.conll")
# data = clean_conll("/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll/P18C6N1_with_pause.conll")


# miscs = []
previous_text_version = 0
previous_sent_id = 0
with open ("output.conll", "w", encoding="utf-8") as f:
	misc =""
	for i in range(len(data)):
		elements = [str(element) for element in data[i]]
		text_version = int(elements[0].split("=")[1]) #literally: # text_version=0
		sent_id = 1

		if text_version == previous_text_version and sent_id <= previous_sent_id:
			sent_id = previous_sent_id + 1

		sentence_complete = elements[2:]

		sentence = ""
		original_tokens = []
		list_elements = []
		for token in sentence_complete:

			conll_columns = token.split("\t")
			list_elements.append(conll_columns)
			item_dict = {'first_elements': tuple(conll_columns[:10]), 'misc': conll_columns[9]} if len(conll_columns) > 1 else {'first_elements': tuple(conll_columns), 'misc': ""}
			original_tokens.append(item_dict)
			
			if len(conll_columns) > 1:
				sentence += conll_columns[1] + " "


		doc = nlp(sentence)
		stanza_nb_tokens = 0
		for j in range(len(doc.sentences)):
			stanza_nb_tokens += len(doc.sentences[j].words)
		list_stanza_elements = []
		if stanza_nb_tokens != len(list_elements):
			for j in range(len(doc.sentences)):
				for i in range(len(doc.sentences[j].words)):
					token = doc.sentences[j].words[i]
					
					xpos = token.xpos if not "None" else "_"
					deps = token.deps if not "None" else "_"
					if j == 0:
						id_to_check_against = token.id
					else:
						id_to_check_against = token.id + len(doc.sentences[j-1].words)
					for element in original_tokens:
						if element['first_elements'][1] == token.text and int(element['first_elements'][0]) == id_to_check_against:
							misc = element['misc']
							break
					list_stanza_elements.append([token.id, token.text, token.lemma, token.pos, xpos, token.feats, token.head, token.deprel, deps, misc])
			new_list = merge_elements(list_elements, list_stanza_elements)
			iterations = 0
			for element in new_list:
				if element[0] == 1:
					mini_sentence = " ".join([token.text for token in doc.sentences[iterations].words])
					if iterations > 0:
						f.write("\n")
					f.write("# text_version=")
					f.write(str(text_version))
					previous_text_version = text_version
					f.write("\n")

					f.write("# sentence_id=")
					f.write(str(sent_id))
					previous_sent_id = sent_id
					sent_id += 1
					f.write("\n")

					f.write(f"# text = {mini_sentence}")
					f.write("\n")

					f.write(f"{element[0]}\t{element[1]}\t{element[2]}\t{element[3]}\t{element[4]}\t{element[5]}\t{element[6]}\t{element[7]}\t{element[8]}\t{element[9]}\n")
					iterations += 1
				else:
					f.write(f"{element[0]}\t{element[1]}\t{element[2]}\t{element[3]}\t{element[4]}\t{element[5]}\t{element[6]}\t{element[7]}\t{element[8]}\t{element[9]}\n")
		else:
			nb_words_in_sentence = []
			for j in range(len(doc.sentences)):
				nb_words_in_sentence.append(len(doc.sentences[j].words))
				mini_sentence = ""
				mini_sentence = " ".join([token.text for token in doc.sentences[j].words])
				# print(mini_sentence)
				if j > 0:
					print("J > 0!!!!!!!!!!!!!!!!")
					f.write("# text_version=")
					f.write(str(text_version))
					previous_text_version = text_version
					f.write("\n")

					f.write("# sentence_id=")
					f.write(str(sent_id))
					previous_sent_id = sent_id
					sent_id += 1
					f.write("\n")

					f.write(f"# text = {mini_sentence}")
					f.write("\n")
				else:
					f.write("# text_version=")
					f.write(str(text_version))
					previous_text_version = text_version
					f.write("\n")

					f.write("# sentence_id=")
					f.write(str(sent_id))
					previous_sent_id = sent_id
					sent_id += 1
					f.write("\n")

					f.write(f"# text = {mini_sentence}")
					f.write("\n")
				for i in range(len(doc.sentences[j].words)):
					token = doc.sentences[j].words[i]
					# print(f"token: {token}")

					xpos = token.xpos if not "None" else "_"
					deps = token.deps if not "None" else "_"
					if j == 0:
						id_to_check_against = token.id
					else:
						id_to_check_against = token.id + sum(nb_words_in_sentence[:j])                    

					for element in original_tokens:

						if element['first_elements'][1] == token.text and int(element['first_elements'][0]) == id_to_check_against:
							misc = element['misc']
							break   
					f.write(f"{token.id}\t{token.text}\t{token.lemma}\t{token.pos}\t{xpos}\t{token.feats}\t{token.head}\t{token.deprel}\t{deps}\t{misc}\n")
				f.write("\n")
# Out:
# original list: [['1', 'Ensuite', 'ensuite', 'ADV', 'ADV', '_', '27', 'mod', '_', 'charID=118__char=E__charStatus=True__pause=1716|charID=103__char=n__charStatus=True__pause=1077|charID=104__char=s__charStatus=True__pause=2309|charID=105__char=u__charStatus=True__pause=2511|charID=106__char=i__charStatus=True__pause=842|charID=107__char=t__charStatus=True__pause=562|charID=108__char=e__charStatus=True__pause=422'], ['2', 'il', 'il', 'CLS', 'CLS', 'n=s|g=m|p=3', '27', 'suj', '_', 'charID=119__char=i__charStatus=True__pause=14009|charID=120__char=l__charStatus=True__pause=437'], ['3', 'faudrait', 'falloir', 'V', 'V', 'n=s|t=C|p=3', '0', 'root', '_', 'charID=122__char=f__charStatus=True__pause=4212|charID=123__char=a__charStatus=True__pause=656|charID=124__char=u__charStatus=True__pause=1248|charID=125__char=d__charStatus=True__pause=2901|charID=126__char=r__charStatus=True__pause=483|charID=127__char=a__charStatus=True__pause=718|charID=128__char=i__charStatus=True__pause=998|charID=129__char=t__charStatus=True__pause=577'], ['4', 'des', 'des', 'DET', 'DET', 'n=p', '29', 'det', '_', 'charID=131__char=d__charStatus=True__pause=14040|charID=132__char=e__charStatus=True__pause=577|charID=133__char=s__charStatus=True__pause=2231'], ['5', 'sortie', 'sortie', 'NC', 'NC', 'n=s|g=f', '27', 'obj', '_', 'charID=135__char=s__charStatus=True__pause=874|charID=136__char=o__charStatus=True__pause=1280|charID=137__char=r__charStatus=True__pause=4946|charID=138__char=t__charStatus=True__pause=608|charID=139__char=i__charStatus=True__pause=1731|charID=140__char=e__charStatus=True__pause=312'], ['6', 'de', 'de', 'P', 'P', '_', '29', 'dep', '_', 'charID=142__char=d__charStatus=True__pause=3260|charID=143__char=e__charStatus=True__pause=281'], ['7', 'secourt', '_', 'NC', 'NC', '_', '30', 'prep', '_', 'charID=145__char=s__charStatus=True__pause=3011|charID=146__char=e__charStatus=True__pause=406|charID=147__char=c__charStatus=True__pause=1669|charID=148__char=o__charStatus=True__pause=1653|charID=149__char=u__charStatus=True__pause=578|charID=150__char=r__charStatus=True__pause=499|charID=151__char=t__charStatus=True__pause=250'], ['8', 'et', 'et', 'CC', 'CC', '_', '27', 'coord', '_', 'charID=153__char=e__charStatus=True__pause=5678|charID=154__char=t__charStatus=True__pause=421'], ['9', 'des', 'de', 'P+D', 'P+D', 'n=p', '32', 'dep_coord', '_', 'charID=156__char=d__charStatus=True__pause=2277|charID=157__char=e__charStatus=True__pause=655|charID=158__char=s__charStatus=True__pause=921'], ['10', 'alarme', 'alarme', 'NC', 'NC', 'n=s|g=f', '33', 'prep', '_', 'charID=160__char=a__charStatus=True__pause=3744|charID=161__char=l__charStatus=True__pause=1060|charID=162__char=a__charStatus=True__pause=1373|charID=163__char=r__charStatus=True__pause=639|charID=164__char=m__charStatus=True__pause=1388|charID=165__char=e__charStatus=True__pause=640'], ['11', '.', '.', 'PONCT', 'PONCT', '_', '34', 'ponct', '_', 'charID=166__char=.__charStatus=True__pause=2293'], ['12', 'Je', 'je', 'CLS', 'CLS', 'n=s|p=1', '37', 'suj', '_', 'charID=167__char=J__charStatus=True__pause=84069|charID=168__char=e__charStatus=True__pause=749'], ['13', 'pense', 'penser', 'V', 'V', 'n=s|t=P,S|p=1,3', '27', 'mod', '_', 'charID=170__char=p__charStatus=True__pause=8720|charID=171__char=e__charStatus=True__pause=530|charID=172__char=n__charStatus=True__pause=889|charID=173__char=s__charStatus=True__pause=686|charID=174__char=e__charStatus=True__pause=249'], ['14', 'aussi', 'aussi', 'ADV', 'ADV', '_', '37', 'mod', '_', 'charID=176__char=a__charStatus=True__pause=2200|charID=177__char=u__charStatus=True__pause=2402|charID=178__char=s__charStatus=True__pause=1201|charID=179__char=s__charStatus=True__pause=250|charID=180__char=i__charStatus=True__pause=1404'], ['15', 'que', 'que', 'CS', 'CS', '_', '37', 'mod', '_', 'charID=182__char=q__charStatus=True__pause=16411|charID=183__char=u__charStatus=True__pause=765|charID=184__char=e__charStatus=True__pause=453'], ['16', 'se', 'se', 'CLR', 'CLR', 'n=p ...
# stanza list: [[1, 'Ensuite', 'ensuite', 'ADV', '_', None, 3, 'advmod', '_', 'charID=118__char=E__charStatus=True__pause=1716|charID=103__char=n__charStatus=True__pause=1077|charID=104__char=s__charStatus=True__pause=2309|charID=105__char=u__charStatus=True__pause=2511|charID=106__char=i__charStatus=True__pause=842|charID=107__char=t__charStatus=True__pause=562|charID=108__char=e__charStatus=True__pause=422'], [2, 'il', 'lui', 'PRON', '_', 'Emph=No|Gender=Masc|Number=Sing|Person=3|PronType=Prs', 3, 'expl:subj', '_', 'charID=119__char=i__charStatus=True__pause=14009|charID=120__char=l__charStatus=True__pause=437'], [3, 'faudrait', 'falloir', 'VERB', '_', 'Mood=Cnd|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 0, 'root', '_', 'charID=122__char=f__charStatus=True__pause=4212|charID=123__char=a__charStatus=True__pause=656|charID=124__char=u__charStatus=True__pause=1248|charID=125__char=d__charStatus=True__pause=2901|charID=126__char=r__charStatus=True__pause=483|charID=127__char=a__charStatus=True__pause=718|charID=128__char=i__charStatus=True__pause=998|charID=129__char=t__charStatus=True__pause=577'], [4, 'des', 'un', 'DET', '_', 'Definite=Ind|Number=Plur|PronType=Art', 5, 'det', '_', 'charID=131__char=d__charStatus=True__pause=14040|charID=132__char=e__charStatus=True__pause=577|charID=133__char=s__charStatus=True__pause=2231'], [5, 'sortie', 'sortie', 'NOUN', '_', 'Gender=Fem|Number=Sing', 3, 'obj', '_', 'charID=135__char=s__charStatus=True__pause=874|charID=136__char=o__charStatus=True__pause=1280|charID=137__char=r__charStatus=True__pause=4946|charID=138__char=t__charStatus=True__pause=608|charID=139__char=i__charStatus=True__pause=1731|charID=140__char=e__charStatus=True__pause=312'], [6, 'de', 'de', 'ADP', '_', None, 7, 'case', '_', 'charID=142__char=d__charStatus=True__pause=3260|charID=143__char=e__charStatus=True__pause=281'], [7, 'secourt', 'secourt', 'NOUN', '_', 'Gender=Masc|Number=Sing', 5, 'nmod', '_', 'charID=145__char=s__charStatus=True__pause=3011|charID=146__char=e__charStatus=True__pause=406|charID=147__char=c__charStatus=True__pause=1669|charID=148__char=o__charStatus=True__pause=1653|charID=149__char=u__charStatus=True__pause=578|charID=150__char=r__charStatus=True__pause=499|charID=151__char=t__charStatus=True__pause=250'], [8, 'et', 'et', 'CCONJ', '_', None, 10, 'cc', '_', 'charID=153__char=e__charStatus=True__pause=5678|charID=154__char=t__charStatus=True__pause=421'], [9, 'des', 'un', 'DET', '_', 'Definite=Ind|Number=Plur|PronType=Art', 10, 'det', '_', 'charID=156__char=d__charStatus=True__pause=2277|charID=157__char=e__charStatus=True__pause=655|charID=158__char=s__charStatus=True__pause=921'], [10, 'alarme', 'alarme', 'NOUN', '_', 'Gender=Fem|Number=Sing', 5, 'conj', '_', 'charID=160__char=a__charStatus=True__pause=3744|charID=161__char=l__charStatus=True__pause=1060|charID=162__char=a__charStatus=True__pause=1373|charID=163__char=r__charStatus=True__pause=639|charID=164__char=m__charStatus=True__pause=1388|charID=165__char=e__charStatus=True__pause=640'], [11, '.', '.', 'PUNCT', '_', None, 3, 'punct', '_', 'charID=166__char=.__charStatus=True__pause=2293'], [1, 'Je', 'moi', 'PRON', '_', 'Number=Sing|Person=1|PronType=Prs', 2, 'nsubj', '_', 'charID=167__char=J__charStatus=True__pause=84069|charID=168__char=e__charStatus=True__pause=749'], [2, 'pense', 'penser', 'VERB', '_', 'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin', 0, 'root', '_', 'charID=170__char=p__charStatus=True__pause=8720|charID=171__char=e__charStatus=True__pause=530|charID=172__char=n__charStatus=True__pause=889|charID=173__char=s__charStatus=True__pause=686|charID=174__char=e__charStatus=True__pause=249'], [3, 'aussi', 'aussi', 'ADV', '_', None, 2, 'advmod', '_', 'charID=176__char=a__charStatus=True__pause=2200|charID=177__char=u__charStatus=True__pause=2402|charID=178__char=s__charStatus=True__pause=1201|charID=179__char=s__charStatus=True__pause=250|charID=180__char=i__charStatus=True__pause=1404'], [4, 'que', 'que', 'SCONJ', ...

# %%
def find_first_difference_index(l_orig, l_stanza):
	# Find the minimum length to avoid index out of range errors
	min_len = min(len(l_orig), len(l_stanza))
	
	# Compare the lists element by element
	for i in range(min_len):
		if l_orig[i] != l_stanza[i]:
			return i
	
	# If no difference was found within the range of the shortest list
	# Check if the lengths are different
	if len(l_orig) != len(l_stanza):
		return min_len
	
	# If no difference is found and lengths are the same
	return -1

# Example usage
l_orig = ["C'", 'etait', 'en', 'décembre', 'je', 'connaisser', 'ce', 'garçon', 'depuis', 'la', 'marenelle', 'il', 'etait', 'très', 'gentil', '.', 'Quand', 'nous', 'sommes', 'rentrée', 'en', 'sixiéme', 'il', 'trainaient', 'avec', 'des', 'quatriéme', 'des', 'garçond']
l_stanza = ["C'", 'etait', 'en', 'décembre', 'je', 'connaisser', 'ce', 'garçon', 'depuis', 'la', 'marenelle', 'il', 'etait', 'très', 'gentil', '.', 'Quand', 'nous', 'sommes', 'rentrée', 'en', 'sixiéme', 'il', 'trainaient', 'avec', 'des', 'quatriéme', 'de', 'les', 'garçond']

index = find_first_difference_index(l_orig, l_stanza)
if index != -1:
	print(f"First difference is at index: {index}")
	print(f"Original: {l_orig[index]}")
else:
	print("No difference found")
# Out:
# First difference is at index: 27
# Original: des

# %%
import stanza
from stanza.models.common.doc import Document

nlp = stanza.Pipeline(lang='en', processors='depparse', depparse_pretagged=True)
pretagged_doc = Document([[{'id': 1, 'text': "C'", 'lemma': 'ce', 'upos': 'CLS', 'xpos': 'DET', 'feats': 'n=s|g=m'}, {'id': 2, 'text': 'etait', 'lemma': 'être', 'upos': 'V', 'xpos': 'NPP', 'feats': '_'}, {'id': 3, 'text': 'en', 'lemma': 'en', 'upos': 'P', 'xpos': 'P', 'feats': '_'}, {'id': 4, 'text': 'décembre', 'lemma': 'décembre', 'upos': 'NC', 'xpos': 'NC', 'feats': 'n=s|g=m'}, {'id': 5, 'text': 'je', 'lemma': 'je', 'upos': 'CLS', 'xpos': 'CLS', 'feats': 'n=s|p=1'}, {'id': 6, 'text': 'connaisser', 'lemma': 'connaître', 'upos': 'V', 'xpos': 'VINF', 'feats': '_'}, {'id': 7, 'text': 'ce', 'lemma': 'ce', 'upos': 'DET', 'xpos': 'DET', 'feats': 'n=s|g=m'}, {'id': 8, 'text': 'garçon', 'lemma': 'garçon', 'upos': 'NC', 'xpos': 'NC', 'feats': 'n=s|g=m'}, {'id': 9, 'text': 'depuis', 'lemma': 'depuis', 'upos': 'P', 'xpos': 'P', 'feats': '_'}, {'id': 10, 'text': 'la', 'lemma': 'le', 'upos': 'DET', 'xpos': 'DET', 'feats': 'n=s|g=f'}, {'id': 11, 'text': 'marenelle', 'lemma': 'maternelle', 'upos': 'NC', 'xpos': 'NC', 'feats': '_'}, {'id': 12, 'text': 'il', 'lemma': 'il', 'upos': 'CLS', 'xpos': 'CLS', 'feats': 'n=s|g=m|p=3'}, {'id': 13, 'text': 'etait', 'lemma': 'être', 'upos': 'V', 'xpos': 'V', 'feats': '_'}, {'id': 14, 'text': 'très', 'lemma': 'très', 'upos': 'ADV', 'xpos': 'ADV', 'feats': '_'}, {'id': 15, 'text': 'gentil', 'lemma': 'gentil', 'upos': 'ADJ', 'xpos': 'ADJ', 'feats': 'n=s|g=m'}, {'id': 16, 'text': '.', 'lemma': '.', 'upos': 'PONCT', 'xpos': 'PONCT', 'feats': '_'}, {'id': 17, 'text': 'Quand', 'lemma': 'quand', 'upos': 'CS', 'xpos': 'CS', 'feats': '_'}, {'id': 18, 'text': 'nous', 'lemma': 'nous', 'upos': 'CLS', 'xpos': 'CLS', 'feats': 'n=p|p=1'}, {'id': 19, 'text': 'sommes', 'lemma': 'être', 'upos': 'V', 'xpos': 'V', 'feats': 'n=p|t=P|p=1'}, {'id': 20, 'text': 'rentrée', 'lemma': 'rentrer', 'upos': 'VPP', 'xpos': 'VPP', 'feats': 'n=s|g=f|t=K'}, {'id': 21, 'text': 'en', 'lemma': 'en', 'upos': 'P', 'xpos': 'P', 'feats': '_'}, {'id': 22, 'text': 'sixiéme', 'lemma': 'sixième', 'upos': 'NC', 'xpos': 'ADV', 'feats': '_'}, {'id': 23, 'text': 'il', 'lemma': 'il', 'upos': 'CLS', 'xpos': 'CLS', 'feats': 'n=s|g=m|p=3'}, {'id': 24, 'text': 'trainaient', 'lemma': 'traîner', 'upos': 'V', 'xpos': 'V', 'feats': '_'}, {'id': 25, 'text': 'avec', 'lemma': 'avec', 'upos': 'P', 'xpos': 'P', 'feats': '_'}, {'id': 26, 'text': 'des', 'lemma': 'un', 'upos': 'DET', 'xpos': 'DET', 'feats': 'n=p'}, {'id': 27, 'text': 'quatriéme', 'lemma': 'quatrième', 'upos': 'NC', 'xpos': 'NC', 'feats': '_'}, {'id': 28, 'text': 'des', 'lemma': 'un', 'upos': 'DET', 'xpos': 'P+D', 'feats': 'n=p'}, {'id': 29, 'text': 'garçond', 'lemma': 'garçon', 'upos': 'NC', 'xpos': 'NC', 'feats': '_'}]
])
doc = nlp(pretagged_doc)
print(doc)
# Out:
# 2024-07-12 17:06:52 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-07-12 17:06:52 INFO: Downloaded file to /Users/madalina/stanza_resources/resources.json
# 2024-07-12 17:06:52 INFO: Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | depparse  | combined_charlm |
# ===============================
#
# 2024-07-12 17:06:52 INFO: Using device: cpu
# 2024-07-12 17:06:52 INFO: Loading: depparse
# 2024-07-12 17:06:53 INFO: Done loading processors!
# [
#   [
#     {
#       "id": 1,
#       "text": "C'",
#       "lemma": "ce",
#       "upos": "CLS",
#       "xpos": "DET",
#       "feats": "n=s|g=m",
#       "head": 2,
#       "deprel": "dep"
#     },
#     {
#       "id": 2,
#       "text": "etait",
#       "lemma": "être",
#       "upos": "V",
#       "xpos": "NPP",
#       "feats": "_",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "en",
#       "lemma": "en",
#       "upos": "P",
#       "xpos": "P",
#       "feats": "_",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 4,
#       "text": "décembre",
#       "lemma": "décembre",
#       "upos": "NC",
#       "xpos": "NC",
#       "feats": "n=s|g=m",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 5,
#       "text": "je",
#       "lemma": "je",
#       "upos": "CLS",
#       "xpos": "CLS",
#       "feats": "n=s|p=1",
#       "head": 6,
#       "deprel": "punct"
#     },
#     {
#       "id": 6,
#       "text": "connaisser",
#       "lemma": "connaître",
#       "upos": "V",
#       "xpos": "VINF",
#       "feats": "_",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 7,
#       "text": "ce",
#       "lemma": "ce",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "n=s|g=m",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 8,
#       "text": "garçon",
#       "lemma": "garçon",
#       "upos": "NC",
#       "xpos": "NC",
#       "feats": "n=s|g=m",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 9,
#       "text": "depuis",
#       "lemma": "depuis",
#       "upos": "P",
#       "xpos": "P",
#       "feats": "_",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 10,
#       "text": "la",
#       "lemma": "le",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "n=s|g=f",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 11,
#       "text": "marenelle",
#       "lemma": "maternelle",
#       "upos": "NC",
#       "xpos": "NC",
#       "feats": "_",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 12,
#       "text": "il",
#       "lemma": "il",
#       "upos": "CLS",
#       "xpos": "CLS",
#       "feats": "n=s|g=m|p=3",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 13,
#       "text": "etait",
#       "lemma": "être",
#       "upos": "V",
#       "xpos": "V",
#       "feats": "_",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 14,
#       "text": "très",
#       "lemma": "très",
#       "upos": "ADV",
#       "xpos": "ADV",
#       "feats": "_",
#       "head": 15,
#       "deprel": "punct"
#     },
#     {
#       "id": 15,
#       "text": "gentil",
#       "lemma": "gentil",
#       "upos": "ADJ",
#       "xpos": "ADJ",
#       "feats": "n=s|g=m",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 16,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PONCT",
#       "xpos": "PONCT",
#       "feats": "_",
#       "head": 17,
#       "deprel": "punct"
#     },
#     {
#       "id": 17,
#       "text": "Quand",
#       "lemma": "quand",
#       "upos": "CS",
#       "xpos": "CS",
#       "feats": "_",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 18,
#       "text": "nous",
#       "lemma": "nous",
#       "upos": "CLS",
#       "xpos": "CLS",
#       "feats": "n=p|p=1",
#       "head": 17,
#       "deprel": "flat"
#     },
#     {
#       "id": 19,
#       "text": "sommes",
#       "lemma": "être",
#       "upos": "V",
#       "xpos": "V",
#       "feats": "n=p|t=P|p=1",
#       "head": 17,
#       "deprel": "flat"
#     },
#     {
#       "id": 20,
#       "text": "rentrée",
#       "lemma": "rentrer",
#       "upos": "VPP",
#       "xpos": "VPP",
#       "feats": "n=s|g=f|t=K",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 21,
#       "text": "en",
#       "lemma": "en",
#       "upos": "P",
#       "xpos": "P",
#       "feats": "_",
#       "head": 22,
#       "deprel": "flat"
#     },
#     {
#       "id": 22,
#       "text": "sixiéme",
#       "lemma": "sixième",
#       "upos": "NC",
#       "xpos": "ADV",
#       "feats": "_",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 23,
#       "text": "il",
#       "lemma": "il",
#       "upos": "CLS",
#       "xpos": "CLS",
#       "feats": "n=s|g=m|p=3",
#       "head": 22,
#       "deprel": "flat"
#     },
#     {
#       "id": 24,
#       "text": "trainaient",
#       "lemma": "traîner",
#       "upos": "V",
#       "xpos": "V",
#       "feats": "_",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 25,
#       "text": "avec",
#       "lemma": "avec",
#       "upos": "P",
#       "xpos": "P",
#       "feats": "_",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 26,
#       "text": "des",
#       "lemma": "un",
#       "upos": "DET",
#       "xpos": "DET",
#       "feats": "n=p",
#       "head": 27,
#       "deprel": "flat"
#     },
#     {
#       "id": 27,
#       "text": "quatriéme",
#       "lemma": "quatrième",
#       "upos": "NC",
#       "xpos": "NC",
#       "feats": "_",
#       "head": 2,
#       "deprel": "flat"
#     },
#     {
#       "id": 28,
#       "text": "des",
#       "lemma": "un",
#       "upos": "DET",
#       "xpos": "P+D",
#       "feats": "n=p",
#       "head": 27,
#       "deprel": "flat"
#     },
#     {
#       "id": 29,
#       "text": "garçond",
#       "lemma": "garçon",
#       "upos": "NC",
#       "xpos": "NC",
#       "feats": "_",
#       "head": 2,
#       "deprel": "flat"
#     }
#   ]
# ]

# %%
# create_new_conll(data, "output.conll")

# for i in range(len(data)):
#     # print(data[0].split("\n"))
#     # print(data[0].split("\n")[2].split("\t")[1])
#     conll_sent = data[i].split("\n")
#     print(conll_sent)
#     sentence_complete = conll_sent[2:]
#     # print(sentence_complete)
#     sentence = ""
#     miscs = []
#     for token in sentence_complete:
#         elements = token.split("\t")
#         # print(elements)
#         miscs.append(elements[9] if len(elements) > 1 else "")
#         if len(elements) > 1:
#             sentence += elements[1] + " "
#     print(sentence)

#     doc = nlp(sentence)
#     print(doc.sentences)
#     # print(miscs)
#     # print(doc.sentences[0].words[0])
#     # for i in range(len(doc.sentences[0].words)):
#     #     token = doc.sentences[0].words[i]
#         # print("============")
#         # print(token.text)
#         # print(miscs[i])

# %%
import stanza

nlp = stanza.Pipeline('fr', processors='tokenize, pos, lemma, depparse')

def extract_sentences(data):
	sentences = []
	miscs = []
	with open ("clean_file.conll", "w", encoding="utf-8") as f:
		for i in range(len(data)):
			conll_sent = data[i].split("\n")
			text_version = conll_sent [0] #literally: # text_version=0
			f.write(text_version + "\n")
			sentence_id = conll_sent[1] #literally: # sentence_id=1
			f.write(sentence_id + "\n")
			sentence_complete = conll_sent[2:]
			sentence = ""
			for token in sentence_complete:
				elements = token.split("\t")
				miscs.append(elements[9] if len(elements) > 1 else "")
				if len(elements) > 1:
					sentence += elements[1] + " "
			f.write(f"# text = {sentence}\n")
			doc = nlp(sentence)
			for i in range(len(doc.sentences[0].words)):
				token = doc.sentences[0].words[i]
				xpos = token.xpos if not "None" else "_"
				deps = token.deps if not "None" else "_"
				f.write(f"{token.id}\t{token.text}\t{token.lemma}\t{token.pos}\t{xpos}\t{token.feats}\t{token.head}\t{token.deprel}\t{deps}\t{miscs[i]}\n")
			f.write("\n")

extract_sentences(data)
# Out:
# 2024-07-10 11:57:28 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-07-10 11:57:28 INFO: Downloaded file to /Users/madalina/stanza_resources/resources.json
# 2024-07-10 11:57:28 WARNING: Language fr package default expects mwt, which has been added
# 2024-07-10 11:57:29 INFO: Loading these models for language: fr (French):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# 2024-07-10 11:57:29 INFO: Using device: cpu
# 2024-07-10 11:57:29 INFO: Loading: tokenize
# 2024-07-10 11:57:29 INFO: Loading: mwt
# 2024-07-10 11:57:29 INFO: Loading: pos
# 2024-07-10 11:57:29 INFO: Loading: lemma
# 2024-07-10 11:57:29 INFO: Loading: depparse
# 2024-07-10 11:57:29 INFO: Done loading processors!

# %%
from conllu import parse_incr, parse

def create_sentences_file(data, output):
	with open(output, "w") as f:
		for i in range(len(data)):
			sent = ""
			sentence = data[i]
			sentence = parse(sentence)
			tokens = sentence[0]
			for token in tokens:
				sent = sent + str(token) + " "
			f.write(sent.strip() + "\n")
	print(f"File {output} created")

create_sentences_file(data, "sentences.txt")
# Out:
# File sentences.txt created

# %%
import stanza

nlp = stanza.Pipeline('fr', processors='tokenize, pos, lemma, depparse')
with open ("sentences.txt", "r") as f:
	for line in f:
		print("====================================")
		doc = nlp(line)
		print(*[f'id: {word.id}\tword: {word.text}\thead id: {word.head}\thead: {sent.words[word.head-1].text if word.head > 0 else "root"}\tdeprel: {word.deprel}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# 2024-07-10 10:51:39 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-07-10 10:51:39 INFO: Downloaded file to /Users/madalina/stanza_resources/resources.json
# 2024-07-10 10:51:39 WARNING: Language fr package default expects mwt, which has been added
# 2024-07-10 10:51:40 INFO: Loading these models for language: fr (French):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# 2024-07-10 10:51:40 INFO: Using device: cpu
# 2024-07-10 10:51:40 INFO: Loading: tokenize
# 2024-07-10 10:51:40 INFO: Loading: mwt
# 2024-07-10 10:51:40 INFO: Loading: pos
# 2024-07-10 10:51:40 INFO: Loading: lemma
# 2024-07-10 10:51:40 INFO: Loading: depparse
# 2024-07-10 10:51:40 INFO: Done loading processors!
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attebn	deprel: det
# id: 16	word: attebn	head id: 14	head: a	deprel: obj
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: atte	deprel: det
# id: 16	word: atte	head id: 14	head: a	deprel: obj
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: atteneeeeeeee	deprel: det
# id: 16	word: atteneeeeeeee	head id: 14	head: a	deprel: obj
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: atten	deprel: det
# id: 16	word: atten	head id: 14	head: a	deprel: obj
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentz	deprel: det
# id: 16	word: attentz	head id: 14	head: a	deprel: obj
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attent	deprel: det
# id: 16	word: attent	head id: 14	head: a	deprel: obj
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 18	head: Charlie	deprel: nmod
# id: 21	word: jen	head id: 23	head: ai	deprel: nsubj
# id: 22	word: '	head id: 21	head: jen	deprel: punct
# id: 23	word: ai	head id: 16	head: attentat	deprel: appos
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 18	head: Charlie	deprel: nmod
# id: 21	word: je	head id: 20	head: moi	deprel: nmod
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 18	head: Charlie	deprel: nmod
# id: 21	word: je	head id: 20	head: moi	deprel: nmod
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 18	head: Charlie	deprel: nmod
# id: 21	word: je	head id: 20	head: moi	deprel: nmod
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 23	head: aime	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 23	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 23	head: aime	deprel: dislocated
# id: 21	word: je	head id: 23	head: aime	deprel: nsubj
# id: 22	word: n'	head id: 23	head: aime	deprel: advmod
# id: 23	word: aime	head id: 4	head: aime	deprel: parataxis
# id: 24	word: pas	head id: 23	head: aime	deprel: advmod
# id: 25	word: la	head id: 26	head: vio	deprel: det
# id: 26	word: vio	head id: 23	head: aime	deprel: obj
# id: 27	word: :	head id: 4	head: aime	deprel: punct
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 23	head: aime	deprel: dislocated
# id: 21	word: je	head id: 23	head: aime	deprel: nsubj
# id: 22	word: n'	head id: 23	head: aime	deprel: advmod
# id: 23	word: aime	head id: 4	head: aime	deprel: parataxis
# id: 24	word: pas	head id: 23	head: aime	deprel: advmod
# id: 25	word: la	head id: 26	head: vi	deprel: det
# id: 26	word: vi	head id: 23	head: aime	deprel: obj
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 23	head: aime	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 23	head: aime	deprel: dislocated
# id: 21	word: je	head id: 23	head: aime	deprel: nsubj
# id: 22	word: n'	head id: 23	head: aime	deprel: advmod
# id: 23	word: aime	head id: 4	head: aime	deprel: parataxis
# id: 24	word: pas	head id: 23	head: aime	deprel: advmod
# id: 25	word: la	head id: 26	head: violence	deprel: det
# id: 26	word: violence	head id: 23	head: aime	deprel: obj
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 18	head: Charlie	deprel: nmod
# id: 21	word: je	head id: 22	head: n'	deprel: nsubj
# id: 22	word: n'	head id: 14	head: a	deprel: advmod
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêvet	deprel: cc
# id: 27	word: j'	head id: 29	head: rêvet	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêvet	deprel: aux:tense
# id: 29	word: rêvet	head id: 4	head: aime	deprel: conj
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 28	head: ai	deprel: cc
# id: 27	word: j'	head id: 28	head: ai	deprel: nsubj
# id: 28	word: ai	head id: 25	head: aimée	deprel: conj
# id: 29	word: rêve	head id: 28	head: ai	deprel: obj:lvc
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 25	head: aimée	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: parv	head id: 38	head: violence	deprel: nmod
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 29	head: rêver	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: par	head id: 4	head: aime	deprel: punct
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 29	head: rêver	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: parce	head id: 44	head: super	deprel: mark
# id: 40	word: '	head id: 39	head: parce	deprel: punct
# id: 41	word: que	head id: 44	head: super	deprel: mark
# id: 42	word: c'	head id: 44	head: super	deprel: nsubj
# id: 43	word: est	head id: 44	head: super	deprel: cop
# id: 44	word: super	head id: 36	head: arrête	deprel: advcl
# id: 45	word: dab	head id: 44	head: super	deprel: fixed
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 29	head: rêver	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: parce	head id: 44	head: super	deprel: mark
# id: 40	word: '	head id: 39	head: parce	deprel: punct
# id: 41	word: que	head id: 44	head: super	deprel: mark
# id: 42	word: c'	head id: 44	head: super	deprel: nsubj
# id: 43	word: est	head id: 44	head: super	deprel: cop
# id: 44	word: super	head id: 36	head: arrête	deprel: advcl
# id: 45	word: da	head id: 44	head: super	deprel: fixed
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 29	head: rêver	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: parce	head id: 45	head: dangeu	deprel: mark
# id: 40	word: '	head id: 39	head: parce	deprel: punct
# id: 41	word: que	head id: 45	head: dangeu	deprel: mark
# id: 42	word: c'	head id: 45	head: dangeu	deprel: nsubj
# id: 43	word: est	head id: 45	head: dangeu	deprel: cop
# id: 44	word: super	head id: 45	head: dangeu	deprel: advmod
# id: 45	word: dangeu	head id: 36	head: arrête	deprel: advcl
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 29	head: rêver	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: parce	head id: 45	head: dange	deprel: mark
# id: 40	word: '	head id: 39	head: parce	deprel: punct
# id: 41	word: que	head id: 45	head: dange	deprel: mark
# id: 42	word: c'	head id: 45	head: dange	deprel: nsubj
# id: 43	word: est	head id: 45	head: dange	deprel: cop
# id: 44	word: super	head id: 45	head: dange	deprel: advmod
# id: 45	word: dange	head id: 36	head: arrête	deprel: advcl
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 29	head: rêver	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: parce	head id: 45	head: dangereus	deprel: mark
# id: 40	word: '	head id: 39	head: parce	deprel: punct
# id: 41	word: que	head id: 45	head: dangereus	deprel: mark
# id: 42	word: c'	head id: 45	head: dangereus	deprel: nsubj
# id: 43	word: est	head id: 45	head: dangereus	deprel: cop
# id: 44	word: super	head id: 45	head: dangereus	deprel: amod
# id: 45	word: dangereus	head id: 36	head: arrête	deprel: advcl
# id: 46	word: parce	head id: 48	head: queon	deprel: case
# id: 47	word: '	head id: 48	head: queon	deprel: punct
# id: 48	word: queon	head id: 45	head: dangereus	deprel: obl:mod
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 29	head: rêver	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: parce	head id: 45	head: dangereus	deprel: mark
# id: 40	word: '	head id: 39	head: parce	deprel: punct
# id: 41	word: que	head id: 45	head: dangereus	deprel: mark
# id: 42	word: c'	head id: 45	head: dangereus	deprel: nsubj
# id: 43	word: est	head id: 45	head: dangereus	deprel: cop
# id: 44	word: super	head id: 45	head: dangereus	deprel: advmod
# id: 45	word: dangereus	head id: 36	head: arrête	deprel: advcl
# id: 46	word: parce	head id: 48	head: que	deprel: mark
# id: 47	word: '	head id: 46	head: parce	deprel: punct
# id: 48	word: que	head id: 45	head: dangereus	deprel: dep
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 29	head: rêver	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: parce	head id: 45	head: dangereus	deprel: mark
# id: 40	word: '	head id: 39	head: parce	deprel: punct
# id: 41	word: que	head id: 45	head: dangereus	deprel: mark
# id: 42	word: c'	head id: 45	head: dangereus	deprel: nsubj
# id: 43	word: est	head id: 45	head: dangereus	deprel: cop
# id: 44	word: super	head id: 45	head: dangereus	deprel: advmod
# id: 45	word: dangereus	head id: 36	head: arrête	deprel: advcl
# id: 46	word: parce	head id: 50	head: peut	deprel: mark
# id: 47	word: '	head id: 46	head: parce	deprel: punct
# id: 48	word: que	head id: 50	head: peut	deprel: mark
# id: 49	word: on	head id: 50	head: peut	deprel: nsubj
# id: 50	word: peut	head id: 45	head: dangereus	deprel: advcl
# id: 51	word: se	head id: 52	head: ble	deprel: obj
# id: 52	word: ble	head id: 50	head: peut	deprel: obj
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 29	head: rêver	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: parce	head id: 45	head: dangereus	deprel: mark
# id: 40	word: '	head id: 39	head: parce	deprel: punct
# id: 41	word: que	head id: 45	head: dangereus	deprel: mark
# id: 42	word: c'	head id: 45	head: dangereus	deprel: nsubj
# id: 43	word: est	head id: 45	head: dangereus	deprel: cop
# id: 44	word: super	head id: 45	head: dangereus	deprel: advmod
# id: 45	word: dangereus	head id: 36	head: arrête	deprel: advcl
# id: 46	word: parce	head id: 50	head: peut	deprel: mark
# id: 47	word: '	head id: 46	head: parce	deprel: punct
# id: 48	word: que	head id: 50	head: peut	deprel: mark
# id: 49	word: on	head id: 50	head: peut	deprel: nsubj
# id: 50	word: peut	head id: 45	head: dangereus	deprel: advcl
# id: 51	word: se	head id: 52	head: bl	deprel: amod
# id: 52	word: bl	head id: 50	head: peut	deprel: xcomp
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 29	head: rêver	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: parce	head id: 45	head: dangereus	deprel: mark
# id: 40	word: '	head id: 39	head: parce	deprel: punct
# id: 41	word: que	head id: 45	head: dangereus	deprel: mark
# id: 42	word: c'	head id: 45	head: dangereus	deprel: nsubj
# id: 43	word: est	head id: 45	head: dangereus	deprel: cop
# id: 44	word: super	head id: 45	head: dangereus	deprel: advmod
# id: 45	word: dangereus	head id: 36	head: arrête	deprel: advcl
# id: 46	word: parce	head id: 50	head: peut	deprel: mark
# id: 47	word: '	head id: 46	head: parce	deprel: punct
# id: 48	word: que	head id: 50	head: peut	deprel: mark
# id: 49	word: on	head id: 50	head: peut	deprel: nsubj
# id: 50	word: peut	head id: 45	head: dangereus	deprel: advcl
# id: 51	word: se	head id: 52	head: blésser	deprel: expl:pv
# id: 52	word: blésser	head id: 50	head: peut	deprel: xcomp
# id: 53	word: .	head id: 4	head: aime	deprel: punct
# id: 1	word: lllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllllll	head id: 0	head: root	deprel: root
# ====================================
# id: 1	word: Moi	head id: 4	head: aime	deprel: dislocated
# id: 2	word: je	head id: 4	head: aime	deprel: nsubj
# id: 3	word: n'	head id: 4	head: aime	deprel: advmod
# id: 4	word: aime	head id: 0	head: root	deprel: root
# id: 5	word: pas	head id: 4	head: aime	deprel: advmod
# id: 6	word: ca	head id: 4	head: aime	deprel: obj
# id: 7	word: la	head id: 8	head: violence	deprel: det
# id: 8	word: violence	head id: 4	head: aime	deprel: obj
# id: 9	word: parce	head id: 14	head: a	deprel: mark
# id: 10	word: '	head id: 9	head: parce	deprel: punct
# id: 11	word: que	head id: 14	head: a	deprel: mark
# id: 12	word: il	head id: 14	head: a	deprel: expl:subj
# id: 13	word: y	head id: 14	head: a	deprel: expl:comp
# id: 14	word: a	head id: 4	head: aime	deprel: advcl
# id: 15	word: une	head id: 16	head: attentat	deprel: det
# id: 16	word: attentat	head id: 14	head: a	deprel: obj
# id: 17	word: de	head id: 18	head: Charlie	deprel: case
# id: 18	word: Charlie	head id: 16	head: attentat	deprel: nmod
# id: 19	word: hedbo	head id: 18	head: Charlie	deprel: flat:name
# id: 20	word: moi	head id: 25	head: aimée	deprel: dislocated
# id: 21	word: je	head id: 25	head: aimée	deprel: nsubj
# id: 22	word: n'	head id: 25	head: aimée	deprel: advmod
# id: 23	word: ai	head id: 25	head: aimée	deprel: aux:tense
# id: 24	word: pas	head id: 25	head: aimée	deprel: advmod
# id: 25	word: aimée	head id: 4	head: aime	deprel: parataxis
# id: 26	word: donc	head id: 29	head: rêver	deprel: cc
# id: 27	word: j'	head id: 29	head: rêver	deprel: nsubj
# id: 28	word: ai	head id: 29	head: rêver	deprel: aux:tense
# id: 29	word: rêver	head id: 25	head: aimée	deprel: conj
# id: 30	word: de	head id: 31	head: ca	deprel: case
# id: 31	word: ca	head id: 29	head: rêver	deprel: obl:arg
# id: 32	word: et	head id: 34	head: aimerai	deprel: cc
# id: 33	word: j'	head id: 34	head: aimerai	deprel: nsubj
# id: 34	word: aimerai	head id: 29	head: rêver	deprel: conj
# id: 35	word: quond	head id: 34	head: aimerai	deprel: advmod
# id: 36	word: arrête	head id: 34	head: aimerai	deprel: xcomp
# id: 37	word: la	head id: 38	head: violence	deprel: det
# id: 38	word: violence	head id: 36	head: arrête	deprel: obj
# id: 39	word: parce	head id: 45	head: dangereus	deprel: mark
# id: 40	word: '	head id: 39	head: parce	deprel: punct
# id: 41	word: que	head id: 45	head: dangereus	deprel: mark
# id: 42	word: c'	head id: 45	head: dangereus	deprel: nsubj
# id: 43	word: est	head id: 45	head: dangereus	deprel: cop
# id: 44	word: super	head id: 45	head: dangereus	deprel: advmod
# id: 45	word: dangereus	head id: 36	head: arrête	deprel: advcl
# id: 46	word: parce	head id: 50	head: peut	deprel: mark
# id: 47	word: '	head id: 46	head: parce	deprel: punct
# id: 48	word: que	head id: 50	head: peut	deprel: mark
# id: 49	word: on	head id: 50	head: peut	deprel: nsubj
# id: 50	word: peut	head id: 45	head: dangereus	deprel: advcl
# id: 51	word: se	head id: 52	head: blésser	deprel: expl:pv
# id: 52	word: blésser	head id: 50	head: peut	deprel: xcomp
# id: 53	word: .	head id: 4	head: aime	deprel: punct

# %%
from stanza.utils.conll import CoNLL

dicts = [[{'id': 1, 'text': 'Test', 'upos': 'NOUN', 'xpos': 'NN', 'feats': 'Number=Sing', 'misc': 'start_char=0|end_char=4'}, {'id': 2, 'text': 'sentence', 'upos': 'NOUN', 'xpos': 'NN', 'feats': 'Number=Sing', 'misc': 'start_char=5|end_char=13'}, {'id': 3, 'text': '.', 'upos': 'PUNCT', 'xpos': '.', 'misc': 'start_char=13|end_char=14'}]] # dicts is List[List[Dict]], representing each token / word in each sentence in the document
conll = CoNLL.convert_dict(dicts) # conll is List[List[List]], representing each token / word in each sentence in the document
print(conll)
# Out:
# [[['1', 'Test', '_', 'NOUN', 'NN', 'Number=Sing', '0', '_', '_', 'start_char=0|end_char=4'], ['2', 'sentence', '_', 'NOUN', 'NN', 'Number=Sing', '1', '_', '_', 'start_char=5|end_char=13'], ['3', '.', '_', 'PUNCT', '.', '_', '2', '_', '_', 'start_char=13|end_char=14']]]

# %%
import stanza

# Download the model (if not already done)
stanza.download('en')

# Initialize the pipeline
nlp = stanza.Pipeline('en')

# Annotate a sentence
doc = nlp("Your sentence here.")  # Replace with your sentence

# Convert to CoNLL format
conll = doc.to_conll()

# Write to a file
with open("output.conll", "w") as f:
	f.write(conll)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-07-10 10:56:27 INFO: Downloaded file to /Users/madalina/stanza_resources/resources.json
# 2024-07-10 10:56:27 INFO: Downloading default packages for language: en (English) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.8.0/models/default.zip:   0%|          | 0…
# 2024-07-10 10:56:44 INFO: Downloaded file to /Users/madalina/stanza_resources/en/default.zip
# 2024-07-10 10:56:45 INFO: Finished downloading models and saved to /Users/madalina/stanza_resources
# 2024-07-10 10:56:45 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-07-10 10:56:45 INFO: Downloaded file to /Users/madalina/stanza_resources/resources.json
# 2024-07-10 10:56:46 INFO: Loading these models for language: en (English):
# ============================================
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | sentiment    | sstplus_charlm            |
# | ner          | ontonotes-ww-multi_charlm |
# ============================================
#
# 2024-07-10 10:56:46 INFO: Using device: cpu
# 2024-07-10 10:56:46 INFO: Loading: tokenize
# 2024-07-10 10:56:46 INFO: Loading: mwt
# 2024-07-10 10:56:46 INFO: Loading: pos
# 2024-07-10 10:56:46 INFO: Loading: lemma
# 2024-07-10 10:56:46 INFO: Loading: constituency
# 2024-07-10 10:56:46 INFO: Loading: depparse
# 2024-07-10 10:56:47 INFO: Loading: sentiment
# 2024-07-10 10:56:47 INFO: Loading: ner
# 2024-07-10 10:56:47 INFO: Done loading processors!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 13
#      10 doc = nlp("Your sentence here.")  # Replace with your sentence
#      12 # Convert to CoNLL format
# ---> 13 conll = doc.to_conll()
#      15 # Write to a file
#      16 with open("output.conll", "w") as f:
#
# AttributeError: 'Document' object has no attribute 'to_conll'

# %%
s = '3	au	à + le	ADP	_	None	5	case	_	charID=879__char=a__charStatus=True__pause=671|charID=880__char=u__charStatus=True__pause=109'
s = s.split("\t")
print(len(s))
# Out:
# 10
