# %%
def add_empty_line_before_text_version(file_path):
	with open(file_path, 'r') as file:
		lines = file.readlines()
	
	modified_lines = []
	for i, line in enumerate(lines):
		if line.startswith("# text_version") and i > 0 and lines[i-1].strip() != "":
			modified_lines.append("\n" + line)  # Add an empty line before this line
		else:
			modified_lines.append(line)
	
	with open(file_path, 'w') as file:  # Overwrite the original file
		file.writelines(modified_lines)

# Example usage
file_path = "/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P06C6N2_with_pause_clean.conll"
add_empty_line_before_text_version(file_path)

# %%
import os
source_dir = "/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean"

#Iterate through all files in the source directory
for file in os.listdir(source_dir):
	source_file_path = os.path.join(source_dir, file)
		
	# Check if it's a file (not a directory)
	if os.path.isfile(source_file_path) and source_file_path.endswith(".conll"):
		# Open the file
		add_empty_line_before_text_version(source_file_path)
		data_file = open(source_file_path, "r")
		sentence = ""
		data = []
		for line in data_file:
			if line[0] == "\n":
				data.append(sentence)
				sentence = ""
			else:
				sentence = sentence + line
		for i in range(len(data)):
			rows = data[i].split("\n")
			tokens = rows[3:-1]

			for token in tokens:

				char_word = ""
				if len(token) > 0:
					token_feats = token.split("\t")

					token_text = token_feats[1]
					token_misc = token_feats[9]
					miscs = token_misc.split("|")
					for misc in miscs:
						misc_feats = misc.split("__")
						char = misc_feats[1].split("=")[1]
						char_word = char_word + char
				if char_word.strip() != token_text.strip():
					print(f"Error found in file {data_file}")
					print(f"Token: {token_text}, Char: {char_word}")
# Out:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P09C6E1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: <UNK>, Char: nul
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18CE2E1_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: &und;, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P19C6E2_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: ave=, Char: ave
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P20CM2E2_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: =, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P20CM2E2_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: =, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P20CM2E2_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: =, Char:
# Error found in file <_io.TextIOWrapper name='/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P20CM2E2_with_pause_clean.conll' mode='r' encoding='utf-8'>
# Token: =, Char:

# %%
import os
source_dir = "/Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean"

#Iterate through all files in the source directory
for file in os.listdir(source_dir):
	if file.startswith("."):
		continue
	source_file_path = os.path.join(source_dir, file)
	print(f"Processing file {source_file_path}")
		
	# Check if it's a file (not a directory)
	if os.path.isfile(source_file_path):
		# Open the file
		add_empty_line_before_text_version(source_file_path)
		data_file = open(source_file_path, "r")
		sentence = ""
		data = []
		for line in data_file:
			if line[0] == "\n":
				data.append(sentence)
				sentence = ""
			else:
				sentence = sentence + line
				
	for i in range(len(data)):
		rows = data[i].split("\n")
		tokens = rows[3:-1]
		try:
			highest_index = tokens[-1].split("\t")[0]


			for token in tokens:
				head = token.split("\t")[6]

				if int(head) > int(highest_index):
					print(f"Error found in file {data_file}")
					print(f"Token: {token}, Head: {head}, highest_index: {highest_index}")
		except IndexError:
			continue
# Out:
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P09C6E1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P17CM2N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P04CE2E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18CE2N2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P12CE2E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P04CM2E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18C6N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P04CE2N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P18CE2E1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P13C6N2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P04CM2N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P17CE2E1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P17CE2N2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P16CM2E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P19CE2E1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P05CE2N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P13CE2N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P04C6E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P16CM2N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P19CE2N2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P05CM2E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P19C6E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P03C6N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P06CE2N2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P20CE2N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P20CM2E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P20CE2E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P03CE2N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P10C6E1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P06CM2E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P03CE2E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P10C6N2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P06C6N2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P06CM2N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P11CM2E1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P07C6E1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P21CE2E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P11CM2N2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P11C6N2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P16C6N1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P14CM2E2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P08CE2N2_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P08CM2E1_with_pause_clean.conll
# Processing file /Users/madalina/Documents/M1TAL/stage_GC/Pro-TEXT_annotated_corpus_v0.3/conll_clean/P11CE2E2_with_pause_clean.conll
